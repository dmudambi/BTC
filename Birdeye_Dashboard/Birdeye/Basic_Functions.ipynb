# %%
import requests
import sys
import json
import base64
import time
import logging
from solders.keypair import Keypair
from solders.transaction import VersionedTransaction 
from solana.rpc.api import Client
from solana.rpc.types import TxOpts
import dontshare as d 
from pprint import pprint
from functools import lru_cache
from datetime import datetime, timedelta
import pytz
import json
import pandas as pd
from pprint import pprint 
from IPython.display import display, HTML
import time

# %%
API_Key = d.birdeye
wallet = d.sol_wallet
chain = "solana"
multichain = "solana,ethereum,bsc"

# %% [markdown]
# ### DEFI APIs

# %% [markdown]
# OHLCV Data

# %%
chain = "solana"
address = "EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm" #WIF
type = "5m"

# Available timeframes:
# "1m"  - 1 minute
# "3m"  - 3 minutes
# "5m"  - 5 minutes
# "15m" - 15 minutes
# "30m" - 30 minutes
# "1H"  - 1 hour
# "2H"  - 2 hours
# "4H"  - 4 hours
# "6H"  - 6 hours
# "8H"  - 8 hours
# "12H" - 12 hours
# "1D"  - 1 day

# Human-readable date and time inputs
start_datetime = "2024-05-19 10:00:00"
end_datetime = "2024-05-19 11:00:00"

# Convert to datetime objects (assuming UTC timezone)
start_dt = datetime.strptime(start_datetime, "%Y-%m-%d %H:%M:%S").replace(tzinfo=pytz.UTC)
end_dt = datetime.strptime(end_datetime, "%Y-%m-%d %H:%M:%S").replace(tzinfo=pytz.UTC)

# Convert to Unix timestamps
time_from = int(start_dt.timestamp())
time_to = int(end_dt.timestamp())

url = f"https://public-api.birdeye.so/defi/ohlcv?address={address}&type={type}&time_from={time_from}&time_to={time_to}"

headers = {
    "accept": "application/json",
    "X-API-KEY": API_Key
}

response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    try:
        # Parse the JSON response
        data = json.loads(response.text)
        
        # Check if 'data' and 'items' keys exist
        if 'data' in data and 'items' in data['data']:
            items = data['data']['items']
            
            if items:  # Check if items list is not empty
                # Convert the list of dictionaries to a pandas DataFrame
                df = pd.DataFrame(items)

                # Convert 'unixTime' to datetime
                df['datetime'] = pd.to_datetime(df['unixTime'], unit='s')

                # Reorder columns to have 'datetime' first
                columns_order = ['datetime'] + [col for col in df.columns if col != 'datetime']
                df = df[columns_order]

                # Style the DataFrame
                styled_df = df.style.set_properties(**{
                    'white-space': 'nowrap',
                    'font-family': 'monospace',
                    'font-size': '10pt',
                    'text-align': 'right'
                }).set_table_styles([
                    {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
                    {'selector': 'td', 'props': [('padding', '5px')]}
                ]).format({
                    'datetime': lambda x: x.strftime('%Y-%m-%d %H:%M:%S'),
                    'o': '{:.2f}',
                    'h': '{:.2f}',
                    'l': '{:.2f}',
                    'c': '{:.2f}',
                    'v': '{:.2f}'
                })

                # Display the styled DataFrame
                display(HTML("<h3>OHLCV Data</h3>"))
                display(HTML(styled_df.to_html()))
            else:
                display(HTML("<h3>No data items found in the response.</h3>"))
                display(HTML("<pre>" + json.dumps(data, indent=2) + "</pre>"))
        else:
            display(HTML("<h3>Unexpected response structure. 'data' or 'items' key not found.</h3>"))
            display(HTML("<pre>" + json.dumps(data, indent=2) + "</pre>"))
    except json.JSONDecodeError:
        display(HTML("<h3>Failed to parse JSON response.</h3>"))
        display(HTML("<pre>" + response.text + "</pre>"))
else:
    display(HTML(f"<h3>Request failed with status code: {response.status_code}</h3>"))
    display(HTML("<pre>" + response.text + "</pre>"))
# Out:
# <h3>OHLCV Data</h3>
# <style type="text/css">
# #T_50ebc th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_50ebc td {
#   padding: 5px;
# }
# #T_50ebc_row0_col0, #T_50ebc_row0_col1, #T_50ebc_row0_col2, #T_50ebc_row0_col3, #T_50ebc_row0_col4, #T_50ebc_row0_col5, #T_50ebc_row0_col6, #T_50ebc_row0_col7, #T_50ebc_row0_col8, #T_50ebc_row1_col0, #T_50ebc_row1_col1, #T_50ebc_row1_col2, #T_50ebc_row1_col3, #T_50ebc_row1_col4, #T_50ebc_row1_col5, #T_50ebc_row1_col6, #T_50ebc_row1_col7, #T_50ebc_row1_col8, #T_50ebc_row2_col0, #T_50ebc_row2_col1, #T_50ebc_row2_col2, #T_50ebc_row2_col3, #T_50ebc_row2_col4, #T_50ebc_row2_col5, #T_50ebc_row2_col6, #T_50ebc_row2_col7, #T_50ebc_row2_col8, #T_50ebc_row3_col0, #T_50ebc_row3_col1, #T_50ebc_row3_col2, #T_50ebc_row3_col3, #T_50ebc_row3_col4, #T_50ebc_row3_col5, #T_50ebc_row3_col6, #T_50ebc_row3_col7, #T_50ebc_row3_col8, #T_50ebc_row4_col0, #T_50ebc_row4_col1, #T_50ebc_row4_col2, #T_50ebc_row4_col3, #T_50ebc_row4_col4, #T_50ebc_row4_col5, #T_50ebc_row4_col6, #T_50ebc_row4_col7, #T_50ebc_row4_col8, #T_50ebc_row5_col0, #T_50ebc_row5_col1, #T_50ebc_row5_col2, #T_50ebc_row5_col3, #T_50ebc_row5_col4, #T_50ebc_row5_col5, #T_50ebc_row5_col6, #T_50ebc_row5_col7, #T_50ebc_row5_col8, #T_50ebc_row6_col0, #T_50ebc_row6_col1, #T_50ebc_row6_col2, #T_50ebc_row6_col3, #T_50ebc_row6_col4, #T_50ebc_row6_col5, #T_50ebc_row6_col6, #T_50ebc_row6_col7, #T_50ebc_row6_col8, #T_50ebc_row7_col0, #T_50ebc_row7_col1, #T_50ebc_row7_col2, #T_50ebc_row7_col3, #T_50ebc_row7_col4, #T_50ebc_row7_col5, #T_50ebc_row7_col6, #T_50ebc_row7_col7, #T_50ebc_row7_col8, #T_50ebc_row8_col0, #T_50ebc_row8_col1, #T_50ebc_row8_col2, #T_50ebc_row8_col3, #T_50ebc_row8_col4, #T_50ebc_row8_col5, #T_50ebc_row8_col6, #T_50ebc_row8_col7, #T_50ebc_row8_col8, #T_50ebc_row9_col0, #T_50ebc_row9_col1, #T_50ebc_row9_col2, #T_50ebc_row9_col3, #T_50ebc_row9_col4, #T_50ebc_row9_col5, #T_50ebc_row9_col6, #T_50ebc_row9_col7, #T_50ebc_row9_col8, #T_50ebc_row10_col0, #T_50ebc_row10_col1, #T_50ebc_row10_col2, #T_50ebc_row10_col3, #T_50ebc_row10_col4, #T_50ebc_row10_col5, #T_50ebc_row10_col6, #T_50ebc_row10_col7, #T_50ebc_row10_col8, #T_50ebc_row11_col0, #T_50ebc_row11_col1, #T_50ebc_row11_col2, #T_50ebc_row11_col3, #T_50ebc_row11_col4, #T_50ebc_row11_col5, #T_50ebc_row11_col6, #T_50ebc_row11_col7, #T_50ebc_row11_col8, #T_50ebc_row12_col0, #T_50ebc_row12_col1, #T_50ebc_row12_col2, #T_50ebc_row12_col3, #T_50ebc_row12_col4, #T_50ebc_row12_col5, #T_50ebc_row12_col6, #T_50ebc_row12_col7, #T_50ebc_row12_col8 {
#   white-space: nowrap;
#   font-family: monospace;
#   font-size: 10pt;
#   text-align: right;
# }
# </style>
# <table id="T_50ebc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50ebc_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_50ebc_level0_col1" class="col_heading level0 col1" >address</th>
#       <th id="T_50ebc_level0_col2" class="col_heading level0 col2" >c</th>
#       <th id="T_50ebc_level0_col3" class="col_heading level0 col3" >h</th>
#       <th id="T_50ebc_level0_col4" class="col_heading level0 col4" >l</th>
#       <th id="T_50ebc_level0_col5" class="col_heading level0 col5" >o</th>
#       <th id="T_50ebc_level0_col6" class="col_heading level0 col6" >type</th>
#       <th id="T_50ebc_level0_col7" class="col_heading level0 col7" >unixTime</th>
#       <th id="T_50ebc_level0_col8" class="col_heading level0 col8" >v</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50ebc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50ebc_row0_col0" class="data row0 col0" >2024-05-19 10:00:00</td>
#       <td id="T_50ebc_row0_col1" class="data row0 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_50ebc_row0_col2" class="data row0 col2" >2.57</td>
#       <td id="T_50ebc_row0_col3" class="data row0 col3" >2.58</td>
#       <td id="T_50ebc_row0_col4" class="data row0 col4" >2.56</td>
#       <td id="T_50ebc_row0_col5" class="data row0 col5" >2.57</td>
#       <td id="T_50ebc_row0_col6" class="data row0 col6" >5m</td>
#       <td id="T_50ebc_row0_col7" class="data row0 col7" >1716112800</td>
#       <td id="T_50ebc_row0_col8" class="data row0 col8" >12346.23</td>
#     </tr>
#     <tr>
#       <th id="T_50ebc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50ebc_row1_col0" class="data row1 col0" >2024-05-19 10:05:00</td>
#       <td id="T_50ebc_row1_col1" class="data row1 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_50ebc_row1_col2" class="data row1 col2" >2.57</td>
#       <td id="T_50ebc_row1_col3" class="data row1 col3" >2.58</td>
#       <td id="T_50ebc_row1_col4" class="data row1 col4" >2.56</td>
#       <td id="T_50ebc_row1_col5" class="data row1 col5" >2.57</td>
#       <td id="T_50ebc_row1_col6" class="data row1 col6" >5m</td>
#       <td id="T_50ebc_row1_col7" class="data row1 col7" >1716113100</td>
#       <td id="T_50ebc_row1_col8" class="data row1 col8" >9304.80</td>
#     </tr>
#     <tr>
#       <th id="T_50ebc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50ebc_row2_col0" class="data row2 col0" >2024-05-19 10:10:00</td>
#       <td id="T_50ebc_row2_col1" class="data row2 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_50ebc_row2_col2" class="data row2 col2" >2.56</td>
#       <td id="T_50ebc_row2_col3" class="data row2 col3" >2.57</td>
#       <td id="T_50ebc_row2_col4" class="data row2 col4" >2.56</td>
#       <td id="T_50ebc_row2_col5" class="data row2 col5" >2.57</td>
#       <td id="T_50ebc_row2_col6" class="data row2 col6" >5m</td>
#       <td id="T_50ebc_row2_col7" class="data row2 col7" >1716113400</td>
#       <td id="T_50ebc_row2_col8" class="data row2 col8" >20782.21</td>
#     </tr>
#     <tr>
#       <th id="T_50ebc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50ebc_row3_col0" class="data row3 col0" >2024-05-19 10:15:00</td>
#       <td id="T_50ebc_row3_col1" class="data row3 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_50ebc_row3_col2" class="data row3 col2" >2.56</td>
#       <td id="T_50ebc_row3_col3" class="data row3 col3" >2.58</td>
#       <td id="T_50ebc_row3_col4" class="data row3 col4" >2.56</td>
#       <td id="T_50ebc_row3_col5" class="data row3 col5" >2.56</td>
#       <td id="T_50ebc_row3_col6" class="data row3 col6" >5m</td>
#       <td id="T_50ebc_row3_col7" class="data row3 col7" >1716113700</td>
#       <td id="T_50ebc_row3_col8" class="data row3 col8" >15130.49</td>
#     </tr>
#     <tr>
#       <th id="T_50ebc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50ebc_row4_col0" class="data row4 col0" >2024-05-19 10:20:00</td>
#       <td id="T_50ebc_row4_col1" class="data row4 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_50ebc_row4_col2" class="data row4 col2" >2.57</td>
#       <td id="T_50ebc_row4_col3" class="data row4 col3" >2.58</td>
#       <td id="T_50ebc_row4_col4" class="data row4 col4" >2.56</td>
#       <td id="T_50ebc_row4_col5" class="data row4 col5" >2.56</td>
#       <td id="T_50ebc_row4_col6" class="data row4 col6" >5m</td>
#       <td id="T_50ebc_row4_col7" class="data row4 col7" >1716114000</td>
#       <td id="T_50ebc_row4_col8" class="data row4 col8" >108256.02</td>
#     </tr>
#     <tr>
#       <th id="T_50ebc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50ebc_row5_col0" class="data row5 col0" >2024-05-19 10:25:00</td>
#       <td id="T_50ebc_row5_col1" class="data row5 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_50ebc_row5_col2" class="data row5 col2" >2.57</td>
#       <td id="T_50ebc_row5_col3" class="data row5 col3" >2.58</td>
#       <td id="T_50ebc_row5_col4" class="data row5 col4" >2.57</td>
#       <td id="T_50ebc_row5_col5" class="data row5 col5" >2.57</td>
#       <td id="T_50ebc_row5_col6" class="data row5 col6" >5m</td>
#       <td id="T_50ebc_row5_col7" class="data row5 col7" >1716114300</td>
#       <td id="T_50ebc_row5_col8" class="data row5 col8" >46453.92</td>
#     </tr>
#     <tr>
#       <th id="T_50ebc_level0_row6"

# %% [markdown]
# ### Token APIs

# %% [markdown]
# Token Security

# %%
url = f"https://public-api.birdeye.so/defi/token_security?address={address}"

headers = {
    "accept": "application/json",
    "X-API-KEY": API_Key
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = json.loads(response.text)
    if 'data' in data:
        # Extract the specific values
        token_data = data['data']
        selected_data = {
            'top10HolderPercent': token_data.get('top10HolderPercent', 'N/A'),
            'top10UserPercent': token_data.get('top10UserPercent', 'N/A'),
            'preMarketHolder': token_data.get('preMarketHolder', 'N/A'),
            'mutableMetadata': token_data.get('mutableMetadata', 'N/A'),
            'creatorPercentage': token_data.get('creatorPercentage', 'N/A'),
            'ownerPercentage': token_data.get('ownerPercentage', 'N/A')
        }

        # Create a DataFrame from the selected data
        df_selected = pd.DataFrame.from_dict(selected_data, orient='index', columns=['Value'])
        df_selected.index.name = 'Attribute'
        df_selected.reset_index(inplace=True)

        # Style the DataFrame
        styled_df = df_selected.style.set_properties(**{
            'white-space': 'pre-wrap',
            'font-family': 'monospace',
            'font-size': '10pt',
            'text-align': 'left'
        }).set_table_styles([
            {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'left')]},
            {'selector': 'td', 'props': [('text-align', 'left')]}
        ])

        # Display the styled DataFrame
        display(HTML("<h3>Selected Token Security Data</h3>"))
        display(HTML(styled_df.to_html()))

        # Display the full data as before
        df = pd.json_normalize(data['data'])
        df = df.map(lambda x: json.dumps(x, indent=2) if isinstance(x, (dict, list)) else x)
        df_pivoted = df.T.reset_index()
        df_pivoted.columns = ['Attribute', 'Value']
        styled_full_df = df_pivoted.style.set_properties(**{
            'white-space': 'pre-wrap',
            'font-family': 'monospace',
            'font-size': '10pt',
            'text-align': 'left'
        }).set_table_styles([
            {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'left')]},
            {'selector': 'td', 'props': [('text-align', 'left')]}
        ])
        #display(HTML("<h3>Full Token Security Data</h3>"))
        #display(HTML(styled_full_df.to_html()))
    else:
        display(HTML("<h3>Unexpected response structure. 'data' key not found.</h3>"))
        display(HTML("<pre>" + json.dumps(data, indent=2) + "</pre>"))
else:
    display(HTML(f"<h3>Request failed with status code: {response.status_code}</h3>"))
    display(HTML("<pre>" + response.text + "</pre>"))
# Out:
# <h3>Selected Token Security Data</h3>
# <style type="text/css">
# #T_9f5a1 th {
#   font-weight: bold;
#   text-align: left;
# }
# #T_9f5a1 td {
#   text-align: left;
# }
# #T_9f5a1_row0_col0, #T_9f5a1_row0_col1, #T_9f5a1_row1_col0, #T_9f5a1_row1_col1, #T_9f5a1_row2_col0, #T_9f5a1_row2_col1, #T_9f5a1_row3_col0, #T_9f5a1_row3_col1, #T_9f5a1_row4_col0, #T_9f5a1_row4_col1, #T_9f5a1_row5_col0, #T_9f5a1_row5_col1 {
#   white-space: pre-wrap;
#   font-family: monospace;
#   font-size: 10pt;
#   text-align: left;
# }
# </style>
# <table id="T_9f5a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f5a1_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_9f5a1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f5a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f5a1_row0_col0" class="data row0 col0" >top10HolderPercent</td>
#       <td id="T_9f5a1_row0_col1" class="data row0 col1" >0.392386</td>
#     </tr>
#     <tr>
#       <th id="T_9f5a1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f5a1_row1_col0" class="data row1 col0" >top10UserPercent</td>
#       <td id="T_9f5a1_row1_col1" class="data row1 col1" >0.392386</td>
#     </tr>
#     <tr>
#       <th id="T_9f5a1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f5a1_row2_col0" class="data row2 col0" >preMarketHolder</td>
#       <td id="T_9f5a1_row2_col1" class="data row2 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9f5a1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f5a1_row3_col0" class="data row3 col0" >mutableMetadata</td>
#       <td id="T_9f5a1_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9f5a1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f5a1_row4_col0" class="data row4 col0" >creatorPercentage</td>
#       <td id="T_9f5a1_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9f5a1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9f5a1_row5_col0" class="data row5 col0" >ownerPercentage</td>
#       <td id="T_9f5a1_row5_col1" class="data row5 col1" >None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Token Overview

# %%
url = f"https://public-api.birdeye.so/defi/token_overview?address={address}"

headers = {
    "accept": "application/json",
    "X-API-KEY": API_Key
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = json.loads(response.text)
    if 'data' in data:
        token_data = data['data']
        selected_data = {
            'address': token_data.get('address', 'N/A'),
            'decimals': token_data.get('decimals', 'N/A'),
            'symbol': token_data.get('symbol', 'N/A'),
            'name': token_data.get('name', 'N/A'),
            'price': token_data.get('price', 'N/A'),
            'liquidity': token_data.get('liquidity', 'N/A'),
            'uniqueWallet30m': token_data.get('uniqueWallet30m', 'N/A'),
            'uniqueWallet30mChangePercent': token_data.get('uniqueWallet30mChangePercent', 'N/A'),
            'uniqueWallet1h': token_data.get('uniqueWallet1h', 'N/A'),
            'uniqueWallet1hChangePercent': token_data.get('uniqueWallet1hChangePercent', 'N/A'),
            'uniqueWallet2h': token_data.get('uniqueWallet2h', 'N/A'),
            'uniqueWallet2hChangePercent': token_data.get('uniqueWallet2hChangePercent', 'N/A'),
            'uniqueWallet4h': token_data.get('uniqueWallet4h', 'N/A'),
            'uniqueWallet4hChangePercent': token_data.get('uniqueWallet4hChangePercent', 'N/A'),
            'uniqueWallet6h': token_data.get('uniqueWallet6h', 'N/A'),
            'uniqueWallet6hChangePercent': token_data.get('uniqueWallet6hChangePercent', 'N/A'),
            'uniqueWallet8h': token_data.get('uniqueWallet8h', 'N/A'),
            'uniqueWallet8hChangePercent': token_data.get('uniqueWallet8hChangePercent', 'N/A'),
            'uniqueWallet12h': token_data.get('uniqueWallet12h', 'N/A'),
            'uniqueWallet12hChangePercent': token_data.get('uniqueWallet12hChangePercent', 'N/A'),
            'uniqueWallet24h': token_data.get('uniqueWallet24h', 'N/A'),
            'uniqueWallet24hChangePercent': token_data.get('uniqueWallet24hChangePercent', 'N/A'),
            'realMc': token_data.get('realMc', 'N/A'),
            'holder': token_data.get('holder', 'N/A'),
            'numberMarkets': token_data.get('numberMarkets', 'N/A'),
            'coingeckoId': token_data.get('extensions', {}).get('coingeckoId', 'N/A'),
            'telegram': token_data.get('extensions', {}).get('telegram', 'N/A'),
            'twitter': token_data.get('extensions', {}).get('twitter', 'N/A'),
            'website': token_data.get('extensions', {}).get('website', 'N/A')
        }

        # Create a DataFrame from the selected data
        df = pd.DataFrame.from_dict(selected_data, orient='index', columns=['Value'])
        df.index.name = 'Attribute'
        df.reset_index(inplace=True)

        # Style the DataFrame
        styled_df = df.style.set_properties(**{
            'white-space': 'pre-wrap',
            'font-family': 'monospace',
            'font-size': '10pt',
            'text-align': 'left'
        }).set_table_styles([
            {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'left')]},
            {'selector': 'td', 'props': [('text-align', 'left')]}
        ])

        # Display the styled DataFrame
        display(HTML("<h3>Selected Token Overview Data</h3>"))
        display(HTML(styled_df.to_html()))
    else:
        display(HTML("<h3>Unexpected response structure. 'data' key not found.</h3>"))
        display(HTML("<pre>" + json.dumps(data, indent=2) + "</pre>"))
else:
    display(HTML(f"<h3>Request failed with status code: {response.status_code}</h3>"))
    display(HTML("<pre>" + response.text + "</pre>"))
# Out:
# <h3>Selected Token Overview Data</h3>
# <style type="text/css">
# #T_ef5ff th {
#   font-weight: bold;
#   text-align: left;
# }
# #T_ef5ff td {
#   text-align: left;
# }
# #T_ef5ff_row0_col0, #T_ef5ff_row0_col1, #T_ef5ff_row1_col0, #T_ef5ff_row1_col1, #T_ef5ff_row2_col0, #T_ef5ff_row2_col1, #T_ef5ff_row3_col0, #T_ef5ff_row3_col1, #T_ef5ff_row4_col0, #T_ef5ff_row4_col1, #T_ef5ff_row5_col0, #T_ef5ff_row5_col1, #T_ef5ff_row6_col0, #T_ef5ff_row6_col1, #T_ef5ff_row7_col0, #T_ef5ff_row7_col1, #T_ef5ff_row8_col0, #T_ef5ff_row8_col1, #T_ef5ff_row9_col0, #T_ef5ff_row9_col1, #T_ef5ff_row10_col0, #T_ef5ff_row10_col1, #T_ef5ff_row11_col0, #T_ef5ff_row11_col1, #T_ef5ff_row12_col0, #T_ef5ff_row12_col1, #T_ef5ff_row13_col0, #T_ef5ff_row13_col1, #T_ef5ff_row14_col0, #T_ef5ff_row14_col1, #T_ef5ff_row15_col0, #T_ef5ff_row15_col1, #T_ef5ff_row16_col0, #T_ef5ff_row16_col1, #T_ef5ff_row17_col0, #T_ef5ff_row17_col1, #T_ef5ff_row18_col0, #T_ef5ff_row18_col1, #T_ef5ff_row19_col0, #T_ef5ff_row19_col1, #T_ef5ff_row20_col0, #T_ef5ff_row20_col1, #T_ef5ff_row21_col0, #T_ef5ff_row21_col1, #T_ef5ff_row22_col0, #T_ef5ff_row22_col1, #T_ef5ff_row23_col0, #T_ef5ff_row23_col1, #T_ef5ff_row24_col0, #T_ef5ff_row24_col1, #T_ef5ff_row25_col0, #T_ef5ff_row25_col1, #T_ef5ff_row26_col0, #T_ef5ff_row26_col1, #T_ef5ff_row27_col0, #T_ef5ff_row27_col1, #T_ef5ff_row28_col0, #T_ef5ff_row28_col1 {
#   white-space: pre-wrap;
#   font-family: monospace;
#   font-size: 10pt;
#   text-align: left;
# }
# </style>
# <table id="T_ef5ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef5ff_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_ef5ff_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef5ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef5ff_row0_col0" class="data row0 col0" >address</td>
#       <td id="T_ef5ff_row0_col1" class="data row0 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef5ff_row1_col0" class="data row1 col0" >decimals</td>
#       <td id="T_ef5ff_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef5ff_row2_col0" class="data row2 col0" >symbol</td>
#       <td id="T_ef5ff_row2_col1" class="data row2 col1" >$WIF</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef5ff_row3_col0" class="data row3 col0" >name</td>
#       <td id="T_ef5ff_row3_col1" class="data row3 col1" >dogwifhat</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef5ff_row4_col0" class="data row4 col0" >price</td>
#       <td id="T_ef5ff_row4_col1" class="data row4 col1" >2.624382</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ef5ff_row5_col0" class="data row5 col0" >liquidity</td>
#       <td id="T_ef5ff_row5_col1" class="data row5 col1" >36975230.723087</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ef5ff_row6_col0" class="data row6 col0" >uniqueWallet30m</td>
#       <td id="T_ef5ff_row6_col1" class="data row6 col1" >384</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ef5ff_row7_col0" class="data row7 col0" >uniqueWallet30mChangePercent</td>
#       <td id="T_ef5ff_row7_col1" class="data row7 col1" >-10.280374</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ef5ff_row8_col0" class="data row8 col0" >uniqueWallet1h</td>
#       <td id="T_ef5ff_row8_col1" class="data row8 col1" >670</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ef5ff_row9_col0" class="data row9 col0" >uniqueWallet1hChangePercent</td>
#       <td id="T_ef5ff_row9_col1" class="data row9 col1" >11.853088</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ef5ff_row10_col0" class="data row10 col0" >uniqueWallet2h</td>
#       <td id="T_ef5ff_row10_col1" class="data row10 col1" >1044</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ef5ff_row11_col0" class="data row11 col0" >uniqueWallet2hChangePercent</td>
#       <td id="T_ef5ff_row11_col1" class="data row11 col1" >-7.936508</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ef5ff_row12_col0" class="data row12 col0" >uniqueWallet4h</td>
#       <td id="T_ef5ff_row12_col1" class="data row12 col1" >1821</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ef5ff_row13_col0" class="data row13 col0" >uniqueWallet4hChangePercent</td>
#       <td id="T_ef5ff_row13_col1" class="data row13 col1" >-21.542439</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ef5ff_row14_col0" class="data row14 col0" >uniqueWallet6h</td>
#       <td id="T_ef5ff_row14_col1" class="data row14 col1" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ef5ff_row15_col0" class="data row15 col0" >uniqueWallet6hChangePercent</td>
#       <td id="T_ef5ff_row15_col1" class="data row15 col1" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ef5ff_row16_col0" class="data row16 col0" >uniqueWallet8h</td>
#       <td id="T_ef5ff_row16_col1" class="data row16 col1" >3602</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ef5ff_row17_col0" class="data row17 col0" >uniqueWallet8hChangePercent</td>
#       <td id="T_ef5ff_row17_col1" class="data row17 col1" >-16.985481</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ef5ff_row18_col0" class="data row18 col0" >uniqueWallet12h</td>
#       <td id="T_ef5ff_row18_col1" class="data row18 col1" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ef5ff_row19_col0" class="data row19 col0" >uniqueWallet12hChangePercent</td>
#       <td id="T_ef5ff_row19_col1" class="data row19 col1" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ef5ff_row20_col0" class="data row20 col0" >uniqueWallet24h</td>
#       <td id="T_ef5ff_row20_col1" class="data row20 col1" >10181</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ef5ff_row21_col0" class="data row21 col0" >uniqueWallet24hChangePercent</td>
#       <td id="T_ef5ff_row21_col1" class="data row21 col1" >-9.518308</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ef5ff_row22_col0" class="data row22 col0" >realMc</td>
#       <td id="T_ef5ff_row22_col1" class="data row22 col1" >2620896607.962399</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ef5ff_row23_col0" class="data row23 col0" >holder</td>
#       <td id="T_ef5ff_row23_col1" class="data row23 col1" >189209</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ef5ff_row24_col0" class="data row24 col0" >numberMarkets</td>
#       <td id="T_ef5ff_row24_col1" class="data row24 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_ef5ff_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e

# %% [markdown]
# Token Trade Data (Single)

# %%
address = "So11111111111111111111111111111111111111112"

url = f"https://public-api.birdeye.so/defi/v3/token/trade-data/single?address={address}"

headers = {
    "accept": "application/json",
    "X-API-KEY": API_Key
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = json.loads(response.text)
    if 'data' in data:
        token_data = data['data']
        
        # Convert the token data to a DataFrame
        df = pd.DataFrame([token_data])
        
        # Transpose the DataFrame for better readability
        df_transposed = df.T.reset_index()
        df_transposed.columns = ['Attribute', 'Value']
        
        # Style the DataFrame
        styled_df = df_transposed.style.set_properties(**{
            'white-space': 'pre-wrap',
            'font-family': 'monospace',
            'font-size': '10pt',
            'text-align': 'left'
        }).set_table_styles([
            {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'left')]},
            {'selector': 'td', 'props': [('text-align', 'left')]}
        ])
        
        # Display the styled DataFrame
        display(HTML("<h3>Token Trade Data</h3>"))
        display(HTML(styled_df.to_html()))
    else:
        print("Unexpected response structure. 'data' key not found.")
        print(json.dumps(data, indent=2))
else:
    print(f"Request failed with status code: {response.status_code}")
    print(response.text)
# Out:
# <h3>Token Trade Data</h3>
# <style type="text/css">
# #T_d2e21 th {
#   font-weight: bold;
#   text-align: left;
# }
# #T_d2e21 td {
#   text-align: left;
# }
# #T_d2e21_row0_col0, #T_d2e21_row0_col1, #T_d2e21_row1_col0, #T_d2e21_row1_col1, #T_d2e21_row2_col0, #T_d2e21_row2_col1, #T_d2e21_row3_col0, #T_d2e21_row3_col1, #T_d2e21_row4_col0, #T_d2e21_row4_col1, #T_d2e21_row5_col0, #T_d2e21_row5_col1, #T_d2e21_row6_col0, #T_d2e21_row6_col1, #T_d2e21_row7_col0, #T_d2e21_row7_col1, #T_d2e21_row8_col0, #T_d2e21_row8_col1, #T_d2e21_row9_col0, #T_d2e21_row9_col1, #T_d2e21_row10_col0, #T_d2e21_row10_col1, #T_d2e21_row11_col0, #T_d2e21_row11_col1, #T_d2e21_row12_col0, #T_d2e21_row12_col1, #T_d2e21_row13_col0, #T_d2e21_row13_col1, #T_d2e21_row14_col0, #T_d2e21_row14_col1, #T_d2e21_row15_col0, #T_d2e21_row15_col1, #T_d2e21_row16_col0, #T_d2e21_row16_col1, #T_d2e21_row17_col0, #T_d2e21_row17_col1, #T_d2e21_row18_col0, #T_d2e21_row18_col1, #T_d2e21_row19_col0, #T_d2e21_row19_col1, #T_d2e21_row20_col0, #T_d2e21_row20_col1, #T_d2e21_row21_col0, #T_d2e21_row21_col1, #T_d2e21_row22_col0, #T_d2e21_row22_col1, #T_d2e21_row23_col0, #T_d2e21_row23_col1, #T_d2e21_row24_col0, #T_d2e21_row24_col1, #T_d2e21_row25_col0, #T_d2e21_row25_col1, #T_d2e21_row26_col0, #T_d2e21_row26_col1, #T_d2e21_row27_col0, #T_d2e21_row27_col1, #T_d2e21_row28_col0, #T_d2e21_row28_col1, #T_d2e21_row29_col0, #T_d2e21_row29_col1, #T_d2e21_row30_col0, #T_d2e21_row30_col1, #T_d2e21_row31_col0, #T_d2e21_row31_col1, #T_d2e21_row32_col0, #T_d2e21_row32_col1, #T_d2e21_row33_col0, #T_d2e21_row33_col1, #T_d2e21_row34_col0, #T_d2e21_row34_col1, #T_d2e21_row35_col0, #T_d2e21_row35_col1, #T_d2e21_row36_col0, #T_d2e21_row36_col1, #T_d2e21_row37_col0, #T_d2e21_row37_col1, #T_d2e21_row38_col0, #T_d2e21_row38_col1, #T_d2e21_row39_col0, #T_d2e21_row39_col1, #T_d2e21_row40_col0, #T_d2e21_row40_col1, #T_d2e21_row41_col0, #T_d2e21_row41_col1, #T_d2e21_row42_col0, #T_d2e21_row42_col1, #T_d2e21_row43_col0, #T_d2e21_row43_col1, #T_d2e21_row44_col0, #T_d2e21_row44_col1, #T_d2e21_row45_col0, #T_d2e21_row45_col1, #T_d2e21_row46_col0, #T_d2e21_row46_col1, #T_d2e21_row47_col0, #T_d2e21_row47_col1, #T_d2e21_row48_col0, #T_d2e21_row48_col1, #T_d2e21_row49_col0, #T_d2e21_row49_col1, #T_d2e21_row50_col0, #T_d2e21_row50_col1, #T_d2e21_row51_col0, #T_d2e21_row51_col1, #T_d2e21_row52_col0, #T_d2e21_row52_col1, #T_d2e21_row53_col0, #T_d2e21_row53_col1, #T_d2e21_row54_col0, #T_d2e21_row54_col1, #T_d2e21_row55_col0, #T_d2e21_row55_col1, #T_d2e21_row56_col0, #T_d2e21_row56_col1, #T_d2e21_row57_col0, #T_d2e21_row57_col1, #T_d2e21_row58_col0, #T_d2e21_row58_col1, #T_d2e21_row59_col0, #T_d2e21_row59_col1, #T_d2e21_row60_col0, #T_d2e21_row60_col1, #T_d2e21_row61_col0, #T_d2e21_row61_col1, #T_d2e21_row62_col0, #T_d2e21_row62_col1, #T_d2e21_row63_col0, #T_d2e21_row63_col1, #T_d2e21_row64_col0, #T_d2e21_row64_col1, #T_d2e21_row65_col0, #T_d2e21_row65_col1, #T_d2e21_row66_col0, #T_d2e21_row66_col1, #T_d2e21_row67_col0, #T_d2e21_row67_col1, #T_d2e21_row68_col0, #T_d2e21_row68_col1, #T_d2e21_row69_col0, #T_d2e21_row69_col1, #T_d2e21_row70_col0, #T_d2e21_row70_col1, #T_d2e21_row71_col0, #T_d2e21_row71_col1, #T_d2e21_row72_col0, #T_d2e21_row72_col1, #T_d2e21_row73_col0, #T_d2e21_row73_col1, #T_d2e21_row74_col0, #T_d2e21_row74_col1, #T_d2e21_row75_col0, #T_d2e21_row75_col1, #T_d2e21_row76_col0, #T_d2e21_row76_col1, #T_d2e21_row77_col0, #T_d2e21_row77_col1, #T_d2e21_row78_col0, #T_d2e21_row78_col1, #T_d2e21_row79_col0, #T_d2e21_row79_col1, #T_d2e21_row80_col0, #T_d2e21_row80_col1, #T_d2e21_row81_col0, #T_d2e21_row81_col1, #T_d2e21_row82_col0, #T_d2e21_row82_col1, #T_d2e21_row83_col0, #T_d2e21_row83_col1, #T_d2e21_row84_col0, #T_d2e21_row84_col1, #T_d2e21_row85_col0, #T_d2e21_row85_col1, #T_d2e21_row86_col0, #T_d2e21_row86_col1, #T_d2e21_row87_col0, #T_d2e21_row87_col1, #T_d2e21_row88_col0, #T_d2e21_row88_col1, #T_d2e21_row89_col0, #T_d2e21_row89_col1, #T_d2e21_row90_col0, #T_d2e21_row90_col1, #T_d2e21_row91_col0, #T_d2e21_row91_col1, #T_d2e21_row92_col0, #T_d2e21_row92_col1, #T_d2e21_row93_col0, #T_d2e21_row93_col1, #T_d2e21_row94_col0, #T_d2e21_row94_col1, #T_d2e21_row95_col0, #T_d2e21_ ...
#   whit

# %% [markdown]
# Trending List

# %%
number_of_tokens = 100

def get_trending_tokens(total_tokens):
    sort_by = "volume24hUSD" # rank, volume24hUSD, liquidity
    sort_type = "desc" # asc, desc
    limit = 20  # API limit per request
    all_tokens = []

    for offset in range(0, total_tokens, limit):
        url = f"https://public-api.birdeye.so/defi/token_trending?sort_by={sort_by}&sort_type={sort_type}&offset={offset}&limit={limit}"

        headers = {
            "accept": "application/json",
            "x-chain": chain,
            "X-API-KEY": API_Key
        }

        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = json.loads(response.text)
            if 'data' in data and 'tokens' in data['data']:
                all_tokens.extend(data['data']['tokens'])
            else:
                print(f"Unexpected response structure at offset {offset}")
                print("Response:", response.text)  # Print the response for debugging
        else:
            print(f"Request failed with status code: {response.status_code} at offset {offset}")
            print("Response:", response.text)  # Print the response for debugging
            break

        if len(all_tokens) >= total_tokens:
            break

    return all_tokens[:total_tokens]

# Get top 100 trending tokens
trending_tokens = get_trending_tokens(number_of_tokens)

if trending_tokens:
    df = pd.DataFrame(trending_tokens)

    # Select and rename columns
    columns_to_display = {
        'symbol': 'Symbol',
        'name': 'Name',
        'price': 'Price',
        'volume24hUSD': 'Volume 24h',
        'liquidity': 'Liquidity',
        'rank': 'Rank'
    }
    df = df[columns_to_display.keys()].rename(columns=columns_to_display)

    # Ensure we have exactly 100 rows
    df = df.head(100)

    # Style the DataFrame
    styled_df = df.style.set_properties(**{
        'white-space': 'nowrap',
        'font-family': 'monospace',
        'font-size': '10pt',
        'text-align': 'right'
    }).set_table_styles([
        {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('padding', '5px')]}
    ]).format({
        'Price': '{:.8f}',
        'Volume 24h': '${:,.2f}',
        'Liquidity': '${:,.2f}',
        'Rank': '{:.0f}'
    })

    # Display the styled DataFrame
    display(HTML(styled_df.to_html()))
else:
    display(HTML("<h3>No trending tokens data available</h3>"))
# Out:
# <style type="text/css">
# #T_f4435 th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_f4435 td {
#   padding: 5px;
# }
# #T_f4435_row0_col0, #T_f4435_row0_col1, #T_f4435_row0_col2, #T_f4435_row0_col3, #T_f4435_row0_col4, #T_f4435_row0_col5, #T_f4435_row1_col0, #T_f4435_row1_col1, #T_f4435_row1_col2, #T_f4435_row1_col3, #T_f4435_row1_col4, #T_f4435_row1_col5, #T_f4435_row2_col0, #T_f4435_row2_col1, #T_f4435_row2_col2, #T_f4435_row2_col3, #T_f4435_row2_col4, #T_f4435_row2_col5, #T_f4435_row3_col0, #T_f4435_row3_col1, #T_f4435_row3_col2, #T_f4435_row3_col3, #T_f4435_row3_col4, #T_f4435_row3_col5, #T_f4435_row4_col0, #T_f4435_row4_col1, #T_f4435_row4_col2, #T_f4435_row4_col3, #T_f4435_row4_col4, #T_f4435_row4_col5, #T_f4435_row5_col0, #T_f4435_row5_col1, #T_f4435_row5_col2, #T_f4435_row5_col3, #T_f4435_row5_col4, #T_f4435_row5_col5, #T_f4435_row6_col0, #T_f4435_row6_col1, #T_f4435_row6_col2, #T_f4435_row6_col3, #T_f4435_row6_col4, #T_f4435_row6_col5, #T_f4435_row7_col0, #T_f4435_row7_col1, #T_f4435_row7_col2, #T_f4435_row7_col3, #T_f4435_row7_col4, #T_f4435_row7_col5, #T_f4435_row8_col0, #T_f4435_row8_col1, #T_f4435_row8_col2, #T_f4435_row8_col3, #T_f4435_row8_col4, #T_f4435_row8_col5, #T_f4435_row9_col0, #T_f4435_row9_col1, #T_f4435_row9_col2, #T_f4435_row9_col3, #T_f4435_row9_col4, #T_f4435_row9_col5, #T_f4435_row10_col0, #T_f4435_row10_col1, #T_f4435_row10_col2, #T_f4435_row10_col3, #T_f4435_row10_col4, #T_f4435_row10_col5, #T_f4435_row11_col0, #T_f4435_row11_col1, #T_f4435_row11_col2, #T_f4435_row11_col3, #T_f4435_row11_col4, #T_f4435_row11_col5, #T_f4435_row12_col0, #T_f4435_row12_col1, #T_f4435_row12_col2, #T_f4435_row12_col3, #T_f4435_row12_col4, #T_f4435_row12_col5, #T_f4435_row13_col0, #T_f4435_row13_col1, #T_f4435_row13_col2, #T_f4435_row13_col3, #T_f4435_row13_col4, #T_f4435_row13_col5, #T_f4435_row14_col0, #T_f4435_row14_col1, #T_f4435_row14_col2, #T_f4435_row14_col3, #T_f4435_row14_col4, #T_f4435_row14_col5, #T_f4435_row15_col0, #T_f4435_row15_col1, #T_f4435_row15_col2, #T_f4435_row15_col3, #T_f4435_row15_col4, #T_f4435_row15_col5, #T_f4435_row16_col0, #T_f4435_row16_col1, #T_f4435_row16_col2, #T_f4435_row16_col3, #T_f4435_row16_col4, #T_f4435_row16_col5, #T_f4435_row17_col0, #T_f4435_row17_col1, #T_f4435_row17_col2, #T_f4435_row17_col3, #T_f4435_row17_col4, #T_f4435_row17_col5, #T_f4435_row18_col0, #T_f4435_row18_col1, #T_f4435_row18_col2, #T_f4435_row18_col3, #T_f4435_row18_col4, #T_f4435_row18_col5, #T_f4435_row19_col0, #T_f4435_row19_col1, #T_f4435_row19_col2, #T_f4435_row19_col3, #T_f4435_row19_col4, #T_f4435_row19_col5, #T_f4435_row20_col0, #T_f4435_row20_col1, #T_f4435_row20_col2, #T_f4435_row20_col3, #T_f4435_row20_col4, #T_f4435_row20_col5, #T_f4435_row21_col0, #T_f4435_row21_col1, #T_f4435_row21_col2, #T_f4435_row21_col3, #T_f4435_row21_col4, #T_f4435_row21_col5, #T_f4435_row22_col0, #T_f4435_row22_col1, #T_f4435_row22_col2, #T_f4435_row22_col3, #T_f4435_row22_col4, #T_f4435_row22_col5, #T_f4435_row23_col0, #T_f4435_row23_col1, #T_f4435_row23_col2, #T_f4435_row23_col3, #T_f4435_row23_col4, #T_f4435_row23_col5, #T_f4435_row24_col0, #T_f4435_row24_col1, #T_f4435_row24_col2, #T_f4435_row24_col3, #T_f4435_row24_col4, #T_f4435_row24_col5, #T_f4435_row25_col0, #T_f4435_row25_col1, #T_f4435_row25_col2, #T_f4435_row25_col3, #T_f4435_row25_col4, #T_f4435_row25_col5, #T_f4435_row26_col0, #T_f4435_row26_col1, #T_f4435_row26_col2, #T_f4435_row26_col3, #T_f4435_row26_col4, #T_f4435_row26_col5, #T_f4435_row27_col0, #T_f4435_row27_col1, #T_f4435_row27_col2, #T_f4435_row27_col3, #T_f4435_row27_col4, #T_f4435_row27_col5, #T_f4435_row28_col0, #T_f4435_row28_col1, #T_f4435_row28_col2, #T_f4435_row28_col3, #T_f4435_row28_col4, #T_f4435_row28_col5, #T_f4435_row29_col0, #T_f4435_row29_col1, #T_f4435_row29_col2, #T_f4435_row29_col3, #T_f4435_row29_col4, #T_f4435_row29_col5, #T_f4435_row30_col0, #T_f4435_row30_col1, #T_f4435_row30_col2, #T_f4435_row30_col3, #T_f4435_row30_col4, #T_f4435_row30_col5, #T_f4435_row31_col0, #T_f4435_row31_col1, #T_f4435_row31_col2, #T_f4435_row31_col3, #T_f4435_row31_col4, #T_f4435_row31_col5, #T_f4435_row32_col0, #T_f443 ...

# %% [markdown]
# New Listings 0-3 days max

# %%
days_back = 1  # Change this value to look back fewer days (1 for 1 day, 2 for 2 days, 3 for 3 days max)
hours_back = 0  # Change this value to look back fewer hours within the selected day
                # Note: when hours_back is 1, it looks back for all new tokens within 1 hour.
                # when hours_back is 0, it looks back for all new tokens within the selected minutes.
minutes_back = 1  # Change this value to look back fewer minutes within the selected hour
liquidity_filter = 10000
def iso8601_to_timestamp(iso_string):
    return int(datetime.fromisoformat(iso_string.replace('Z', '+00:00')).timestamp())

def get_new_listings(days_back, hours_back, minutes_back):
    end_time = datetime.now(pytz.UTC)
    
    if days_back == 1:
        start_time = end_time - timedelta(hours=hours_back, minutes=minutes_back)
    elif days_back == 2:
        start_time = end_time - timedelta(days=1, hours=hours_back, minutes=minutes_back)
    elif days_back == 3:
        start_time = end_time - timedelta(days=2, hours=hours_back, minutes=minutes_back)
    else:
        raise ValueError("days_back must be 1, 2, or 3")
    
    all_tokens = []
    current_time = int(end_time.timestamp())
    
    while current_time > int(start_time.timestamp()):
        url = f"https://public-api.birdeye.so/defi/v2/tokens/new_listing?time_to={current_time}&limit=10"

        headers = {
            "accept": "application/json",
            "X-API-KEY": API_Key
        }

        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = response.json()
            if 'data' in data and 'items' in data['data']:
                new_tokens = data['data']['items']
                if not new_tokens:
                    break
                all_tokens.extend(new_tokens)
                current_time = min(iso8601_to_timestamp(token['liquidityAddedAt']) for token in new_tokens)
            else:
                print(f"Unexpected response structure")
                print("Response:", response.text)
                break
        else:
            print(f"Request failed with status code: {response.status_code}")
            print("Response:", response.text)
            break

        # Respect rate limits
        time.sleep(1)

    # Remove duplicates based on 'address'
    unique_tokens = list({token['address']: token for token in all_tokens}.values())
    
    return unique_tokens

# Get new listings for the past X days, Y hours, and Z minutes
new_listings = get_new_listings(days_back, hours_back, minutes_back)

if new_listings:
    # Display full list of tokens
    df_full = pd.DataFrame(new_listings)
    
    # Convert liquidityAddedAt to datetime
    df_full['liquidityAddedAt'] = pd.to_datetime(df_full['liquidityAddedAt'])
    
    # Sort by liquidityAddedAt in descending order
    df_full = df_full.sort_values('liquidityAddedAt', ascending=False)
    
    # Style the full DataFrame
    styled_df_full = df_full.style.set_properties(**{
        'white-space': 'nowrap',
        'font-family': 'monospace',
        'font-size': '10pt',
        'text-align': 'right'
    }).set_table_styles([
        {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('padding', '5px')]}
    ]).format({
        'liquidity': '{:.8f}',
        'liquidityAddedAt': lambda x: x.strftime('%Y-%m-%d %H:%M:%S')
    })

    # Display the full list
    time_period = f"{days_back} day{'s' if days_back > 1 else ''}, {hours_back} hour{'s' if hours_back > 1 else ''}, and {minutes_back} minute{'s' if minutes_back > 1 else ''}"
    #display(HTML(f"<h3>Full List of New Listings (Past {time_period}) - Total: {len(new_listings)}</h3>"))
    #display(HTML(styled_df_full.to_html()))

    # Apply filters for the second table
    df_filtered = df_full[
        (df_full['name'].notna() & (df_full['name'] != 'None')) & 
        (df_full['logoURI'].notna() & (df_full['logoURI'] != 'None')) & 
        (df_full['liquidity'].astype(float) >= liquidity_filter)
    ]

    # Check if there are any rows left after filtering
    if not df_filtered.empty:
        # Style the filtered DataFrame
        styled_df_filtered = df_filtered.style.set_properties(**{
            'white-space': 'nowrap',
            'font-family': 'monospace',
            'font-size': '10pt',
            'text-align': 'right'
        }).set_table_styles([
            {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
            {'selector': 'td', 'props': [('padding', '5px')]}
        ]).format({
            'liquidity': '{:.8f}',
            'liquidityAddedAt': lambda x: x.strftime('%Y-%m-%d %H:%M:%S')
        })

        # Display the filtered table
        display(HTML(f"<h3>Filtered New Listings (Past {time_period}) - Total: {len(df_filtered)}</h3>"))
        display(HTML(styled_df_filtered.to_html()))
    else:
        display(HTML("<h3>No listings match the specified criteria</h3>"))
else:
    display(HTML("<h3>No new listings data available</h3>"))
# Out:
# <h3>Filtered New Listings (Past 1 day, 0 hour, and 1 minute) - Total: 1</h3>
# <style type="text/css">
# #T_7f16f th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_7f16f td {
#   padding: 5px;
# }
# #T_7f16f_row0_col0, #T_7f16f_row0_col1, #T_7f16f_row0_col2, #T_7f16f_row0_col3, #T_7f16f_row0_col4, #T_7f16f_row0_col5, #T_7f16f_row0_col6 {
#   white-space: nowrap;
#   font-family: monospace;
#   font-size: 10pt;
#   text-align: right;
# }
# </style>
# <table id="T_7f16f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f16f_level0_col0" class="col_heading level0 col0" >address</th>
#       <th id="T_7f16f_level0_col1" class="col_heading level0 col1" >symbol</th>
#       <th id="T_7f16f_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_7f16f_level0_col3" class="col_heading level0 col3" >decimals</th>
#       <th id="T_7f16f_level0_col4" class="col_heading level0 col4" >liquidityAddedAt</th>
#       <th id="T_7f16f_level0_col5" class="col_heading level0 col5" >logoURI</th>
#       <th id="T_7f16f_level0_col6" class="col_heading level0 col6" >liquidity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f16f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f16f_row0_col0" class="data row0 col0" >F2L39M7UFfjCXwFBLMGyaVpgVMsMAy7wG3edAj9Ppump</td>
#       <td id="T_7f16f_row0_col1" class="data row0 col1" >BIP-BUP</td>
#       <td id="T_7f16f_row0_col2" class="data row0 col2" >BIP-BUP</td>
#       <td id="T_7f16f_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_7f16f_row0_col4" class="data row0 col4" >2024-10-17 05:09:32</td>
#       <td id="T_7f16f_row0_col5" class="data row0 col5" >https://ipfs.io/ipfs/QmNXMu6vfFJzNmWXak7VeuNnqYYwGTFNdEWeAwte3E4uDK</td>
#       <td id="T_7f16f_row0_col6" class="data row0 col6" >24533.07837692</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Top Traders

# %%
# Example usage
address = "EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm"
time_frame = "30m"  # 30m, 1h, 4h, 6h, 8h, 12h, 24h
sort_type = "desc"  # asc, desc
sort_by = "volume"  # trade, volume 
            # Note: trade is the number of transactions made, volume is the total volume of transactions made
total_traders = 20  # Change this to the number of top traders you want to retrieve

def get_top_traders(address, time_frame, sort_type, sort_by, total_traders):
    limit = 10
    all_traders = []

    for offset in range(0, total_traders, limit):
        url = f"https://public-api.birdeye.so/defi/v2/tokens/top_traders?address={address}&time_frame={time_frame}&sort_type={sort_type}&sort_by={sort_by}&offset={offset}&limit={limit}"

        headers = {
            "accept": "application/json",
            "X-API-KEY": API_Key
        }

        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = json.loads(response.text)
            if 'data' in data and 'items' in data['data']:
                all_traders.extend(data['data']['items'])
            else:
                print(f"Unexpected response structure at offset {offset}")
                break
        else:
            print(f"Request failed with status code: {response.status_code} at offset {offset}")
            break

        if len(all_traders) >= total_traders:
            break

        # Respect rate limits
        time.sleep(1)

    return all_traders[:total_traders]



top_traders = get_top_traders(address, time_frame, sort_type, sort_by, total_traders)

if top_traders:
    df = pd.DataFrame(top_traders)

    # Style the DataFrame
    styled_df = df.style.set_properties(**{
        'white-space': 'nowrap',
        'font-family': 'monospace',
        'font-size': '10pt',
        'text-align': 'right'
    }).set_table_styles([
        {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('padding', '5px')]}
    ]).format({
        'trade': '{:,.0f}',
        'volume': '${:,.2f}',
        'buyVolume': '${:,.2f}',
        'sellVolume': '${:,.2f}'
    })

    # Display the styled DataFrame
    display(HTML(f"<h3>Top {total_traders} Traders for {address} (Time Frame: {time_frame})</h3>"))
    display(HTML(styled_df.to_html()))
else:
    display(HTML("<h3>No top traders data available</h3>"))
# Out:
# <h3>Top 20 Traders for EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm (Time Frame: 30m)</h3>
# <style type="text/css">
# #T_a525f th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_a525f td {
#   padding: 5px;
# }
# #T_a525f_row0_col0, #T_a525f_row0_col1, #T_a525f_row0_col2, #T_a525f_row0_col3, #T_a525f_row0_col4, #T_a525f_row0_col5, #T_a525f_row0_col6, #T_a525f_row0_col7, #T_a525f_row0_col8, #T_a525f_row0_col9, #T_a525f_row1_col0, #T_a525f_row1_col1, #T_a525f_row1_col2, #T_a525f_row1_col3, #T_a525f_row1_col4, #T_a525f_row1_col5, #T_a525f_row1_col6, #T_a525f_row1_col7, #T_a525f_row1_col8, #T_a525f_row1_col9, #T_a525f_row2_col0, #T_a525f_row2_col1, #T_a525f_row2_col2, #T_a525f_row2_col3, #T_a525f_row2_col4, #T_a525f_row2_col5, #T_a525f_row2_col6, #T_a525f_row2_col7, #T_a525f_row2_col8, #T_a525f_row2_col9, #T_a525f_row3_col0, #T_a525f_row3_col1, #T_a525f_row3_col2, #T_a525f_row3_col3, #T_a525f_row3_col4, #T_a525f_row3_col5, #T_a525f_row3_col6, #T_a525f_row3_col7, #T_a525f_row3_col8, #T_a525f_row3_col9, #T_a525f_row4_col0, #T_a525f_row4_col1, #T_a525f_row4_col2, #T_a525f_row4_col3, #T_a525f_row4_col4, #T_a525f_row4_col5, #T_a525f_row4_col6, #T_a525f_row4_col7, #T_a525f_row4_col8, #T_a525f_row4_col9, #T_a525f_row5_col0, #T_a525f_row5_col1, #T_a525f_row5_col2, #T_a525f_row5_col3, #T_a525f_row5_col4, #T_a525f_row5_col5, #T_a525f_row5_col6, #T_a525f_row5_col7, #T_a525f_row5_col8, #T_a525f_row5_col9, #T_a525f_row6_col0, #T_a525f_row6_col1, #T_a525f_row6_col2, #T_a525f_row6_col3, #T_a525f_row6_col4, #T_a525f_row6_col5, #T_a525f_row6_col6, #T_a525f_row6_col7, #T_a525f_row6_col8, #T_a525f_row6_col9, #T_a525f_row7_col0, #T_a525f_row7_col1, #T_a525f_row7_col2, #T_a525f_row7_col3, #T_a525f_row7_col4, #T_a525f_row7_col5, #T_a525f_row7_col6, #T_a525f_row7_col7, #T_a525f_row7_col8, #T_a525f_row7_col9, #T_a525f_row8_col0, #T_a525f_row8_col1, #T_a525f_row8_col2, #T_a525f_row8_col3, #T_a525f_row8_col4, #T_a525f_row8_col5, #T_a525f_row8_col6, #T_a525f_row8_col7, #T_a525f_row8_col8, #T_a525f_row8_col9, #T_a525f_row9_col0, #T_a525f_row9_col1, #T_a525f_row9_col2, #T_a525f_row9_col3, #T_a525f_row9_col4, #T_a525f_row9_col5, #T_a525f_row9_col6, #T_a525f_row9_col7, #T_a525f_row9_col8, #T_a525f_row9_col9, #T_a525f_row10_col0, #T_a525f_row10_col1, #T_a525f_row10_col2, #T_a525f_row10_col3, #T_a525f_row10_col4, #T_a525f_row10_col5, #T_a525f_row10_col6, #T_a525f_row10_col7, #T_a525f_row10_col8, #T_a525f_row10_col9, #T_a525f_row11_col0, #T_a525f_row11_col1, #T_a525f_row11_col2, #T_a525f_row11_col3, #T_a525f_row11_col4, #T_a525f_row11_col5, #T_a525f_row11_col6, #T_a525f_row11_col7, #T_a525f_row11_col8, #T_a525f_row11_col9, #T_a525f_row12_col0, #T_a525f_row12_col1, #T_a525f_row12_col2, #T_a525f_row12_col3, #T_a525f_row12_col4, #T_a525f_row12_col5, #T_a525f_row12_col6, #T_a525f_row12_col7, #T_a525f_row12_col8, #T_a525f_row12_col9, #T_a525f_row13_col0, #T_a525f_row13_col1, #T_a525f_row13_col2, #T_a525f_row13_col3, #T_a525f_row13_col4, #T_a525f_row13_col5, #T_a525f_row13_col6, #T_a525f_row13_col7, #T_a525f_row13_col8, #T_a525f_row13_col9, #T_a525f_row14_col0, #T_a525f_row14_col1, #T_a525f_row14_col2, #T_a525f_row14_col3, #T_a525f_row14_col4, #T_a525f_row14_col5, #T_a525f_row14_col6, #T_a525f_row14_col7, #T_a525f_row14_col8, #T_a525f_row14_col9, #T_a525f_row15_col0, #T_a525f_row15_col1, #T_a525f_row15_col2, #T_a525f_row15_col3, #T_a525f_row15_col4, #T_a525f_row15_col5, #T_a525f_row15_col6, #T_a525f_row15_col7, #T_a525f_row15_col8, #T_a525f_row15_col9, #T_a525f_row16_col0, #T_a525f_row16_col1, #T_a525f_row16_col2, #T_a525f_row16_col3, #T_a525f_row16_col4, #T_a525f_row16_col5, #T_a525f_row16_col6, #T_a525f_row16_col7, #T_a525f_row16_col8, #T_a525f_row16_col9, #T_a525f_row17_col0, #T_a525f_row17_col1, #T_a525f_row17_col2, #T_a525f_row17_col3, #T_a525f_row17_col4, #T_a525f_row17_col5, #T_a525f_row17_col6, #T_a525f_row17_col7, #T_a525f_row17_col8, #T_a525f_row17_col9, #T_a525f_row18_col0, #T_a525f_row18_col1, #T_a525f_row18_col2, #T_a525f_row18_col3, #T_a525f_row18_col4, #T_a525f_row18_col5, #T_a525f_row18_col6, #T_a525f_row18_col7, #T_a525f_row18_col8, #T_a525f_row18_col9, #T_a525f_row19_col0, #T_a525f_row19_col1, #T_a525f_row19_col2, #T_a525f_row19_col3, #T_a525f_row19_col4, #T_a5 ...
#   white-space: nowrap;
#   font-family: monospace;
#   font-size: 10pt;
#   text-align: right;
# }
# </style>
# <table id="T_a525f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a525f_level0_col0" class="col_heading level0 col0" >tokenAddress</th>
#       <th id="T_a525f_level0_col1" class="col_heading level0 col1" >owner</th>
#       <th id="T_a525f_level0_col2" class="col_heading level0 col2" >tags</th>
#       <th id="T_a525f_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_a525f_level0_col4" class="col_heading level0 col4" >volume</th>
#       <th id="T_a525f_level0_col5" class="col_heading level0 col5" >trade</th>
#       <th id="T_a525f_level0_col6" class="col_heading level0 col6" >tradeBuy</th>
#       <th id="T_a525f_level0_col7" class="col_heading level0 col7" >tradeSell</th>
#       <th id="T_a525f_level0_col8" class="col_heading level0 col8" >volumeBuy</th>
#       <th id="T_a525f_level0_col9" class="col_heading level0 col9" >volumeSell</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a525f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a525f_row0_col0" class="data row0 col0" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_a525f_row0_col1" class="data row0 col1" >MfDuWeqSHEqTFVYZ7LoexgAK9dxk7cy4DFJWjWMGVWa</td>
#       <td id="T_a525f_row0_col2" class="data row0 col2" >[]</td>
#       <td id="T_a525f_row0_col3" class="data row0 col3" >30m</td>
#       <td id="T_a525f_row0_col4" class="data row0 col4" >$35,924.80</td>
#       <td id="T_a525f_row0_col5" class="data row0 col5" >193</td>
#       <td id="T_a525f_row0_col6" class="data row0 col6" >111</td>
#       <td id="T_a525f_row0_col7" class="data row0 col7" >82</td>
#       <td id="T_a525f_row0_col8" class="data row0 col8" >21908.942141</td>
#       <td id="T_a525f_row0_col9" class="data row0 col9" >14015.855342</td>
#     </tr>
#     <tr>
#       <th id="T_a525f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a525f_row1_col0" class="data row1 col0" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_a525f_row1_col1" class="data row1 col1" >Fd48hVrg4QQznwi8eCJjCfNsbnSxb1ty5rJ5xvSMCXXr</td>
#       <td id="T_a525f_row1_col2" class="data row1 col2" >[]</td>
#       <td id="T_a525f_row1_col3" class="data row1 col3" >30m</td>
#       <td id="T_a525f_row1_col4" class="data row1 col4" >$11,258.45</td>
#       <td id="T_a525f_row1_col5" class="data row1 col5" >36</td>
#       <td id="T_a525f_row1_col6" class="data row1 col6" >23</td>
#       <td id="T_a525f_row1_col7" class="data row1 col7" >13</td>
#       <td id="T_a525f_row1_col8" class="data row1 col8" >7802.450017</td>
#       <td id="T_a525f_row1_col9" class="data row1 col9" >3455.996330</td>
#     </tr>
#     <tr>
#       <th id="T_a525f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a525f_row2_col0" class="data row2 col0" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_a525f_row2_col1" class="data row2 col1" >9AHhmgoxnFq9UP4LDGPRv9z3oxiL3G2E4Dys1LyYNa1c</td>
#       <td id="T_a525f_row2_col2" class="data row2 col2" >[]</td>
#       <td id="T_a525f_row2_col3" class="data row2 col3" >30m</td>
#       <td id="T_a525f_row2_col4" class="data row2 col4" >$10,446.14</td>
#       <td id="T_a525f_row2_col5" class="data row2 col5" >24</td>
#       <td id="T_a525f_row2_col6" class="data row2 col6" >11</td>
#       <td id="T_a525f_row2_col7" class="data row2 col7" >13</td>
#       <td id="T_a525f_row2_col8" class="data row2 col8" >5298.682933</td>
#       <td id="T_a525f_row2_col9" class="data row2 col9" >5147.460635</td>
#     </tr>
#     <tr>
#       <th id="T_a525f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a525f_row3_col0" class="data row3 col0" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td

# %% [markdown]
# Top Markets for a Token

# %%
# Example usage
address = "EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm"
time_frame = "24h"  # 30m, 1h, 4h, 6h, 8h, 12h, 24h 
sort_type = "desc"  # asc, desc
sort_by = "volume24h"  # volume24h, liquidity
total_markets = 50  # Change this to the number of markets you want to retrieve

def get_markets(address, time_frame, sort_type, sort_by, total_markets):
    limit = 10
    all_markets = []

    for offset in range(0, total_markets, limit):
        url = f"https://public-api.birdeye.so/defi/v2/markets?address={address}&time_frame={time_frame}&sort_type={sort_type}&sort_by={sort_by}&offset={offset}&limit={limit}"

        headers = {
            "accept": "application/json",
            "X-API-KEY": API_Key
        }

        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = json.loads(response.text)
            if 'data' in data and 'items' in data['data']:
                all_markets.extend(data['data']['items'])
            else:
                print(f"Unexpected response structure at offset {offset}")
                break
        else:
            print(f"Request failed with status code: {response.status_code} at offset {offset}")
            break

        if len(all_markets) >= total_markets:
            break

        # Respect rate limits
        time.sleep(1)

    return all_markets[:total_markets]



markets = get_markets(address, time_frame, sort_type, sort_by, total_markets)

if markets:
    df = pd.DataFrame(markets)

    # Flatten nested dictionaries
    df['base_address'] = df['base'].apply(lambda x: x.get('address'))
    df['base_symbol'] = df['base'].apply(lambda x: x.get('symbol'))
    df['quote_address'] = df['quote'].apply(lambda x: x.get('address'))
    df['quote_symbol'] = df['quote'].apply(lambda x: x.get('symbol'))

    # Select and rename columns based on available data
    columns_to_display = {
        'address': 'Market Address',
        'name': 'Name',
        'base_symbol': 'Base Symbol',
        'quote_symbol': 'Quote Symbol',
        'liquidity': 'Liquidity',
        'volume24h': 'Volume 24h',
        'price': 'Price',
        'trade24h': 'Trades 24h',
        'uniqueWallet24h': 'Unique Wallets 24h',
        'source': 'Source'
    }
    
    # Only include columns that exist in the DataFrame
    available_columns = [col for col in columns_to_display.keys() if col in df.columns]
    df = df[available_columns].rename(columns={col: columns_to_display[col] for col in available_columns})

    # Style the DataFrame
    styled_df = df.style.set_properties(**{
        'white-space': 'nowrap',
        'font-family': 'monospace',
        'font-size': '10pt',
        'text-align': 'right'
    }).set_table_styles([
        {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('padding', '5px')]}
    ]).format({
        'Liquidity': '${:,.2f}',
        'Volume 24h': '${:,.2f}',
        'Price': '{:,.8f}',
        'Trades 24h': '{:,}',
        'Unique Wallets 24h': '{:,}'
    })

    # Display the styled DataFrame
    display(HTML(f"<h3>Top {len(df)} Markets for {address} (Time Frame: {time_frame})</h3>"))
    display(HTML(styled_df.to_html()))
else:
    display(HTML("<h3>No markets data available</h3>"))
# Out:
# <h3>Top 50 Markets for EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm (Time Frame: 24h)</h3>
# <style type="text/css">
# #T_faea8 th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_faea8 td {
#   padding: 5px;
# }
# #T_faea8_row0_col0, #T_faea8_row0_col1, #T_faea8_row0_col2, #T_faea8_row0_col3, #T_faea8_row0_col4, #T_faea8_row0_col5, #T_faea8_row0_col6, #T_faea8_row0_col7, #T_faea8_row0_col8, #T_faea8_row0_col9, #T_faea8_row1_col0, #T_faea8_row1_col1, #T_faea8_row1_col2, #T_faea8_row1_col3, #T_faea8_row1_col4, #T_faea8_row1_col5, #T_faea8_row1_col6, #T_faea8_row1_col7, #T_faea8_row1_col8, #T_faea8_row1_col9, #T_faea8_row2_col0, #T_faea8_row2_col1, #T_faea8_row2_col2, #T_faea8_row2_col3, #T_faea8_row2_col4, #T_faea8_row2_col5, #T_faea8_row2_col6, #T_faea8_row2_col7, #T_faea8_row2_col8, #T_faea8_row2_col9, #T_faea8_row3_col0, #T_faea8_row3_col1, #T_faea8_row3_col2, #T_faea8_row3_col3, #T_faea8_row3_col4, #T_faea8_row3_col5, #T_faea8_row3_col6, #T_faea8_row3_col7, #T_faea8_row3_col8, #T_faea8_row3_col9, #T_faea8_row4_col0, #T_faea8_row4_col1, #T_faea8_row4_col2, #T_faea8_row4_col3, #T_faea8_row4_col4, #T_faea8_row4_col5, #T_faea8_row4_col6, #T_faea8_row4_col7, #T_faea8_row4_col8, #T_faea8_row4_col9, #T_faea8_row5_col0, #T_faea8_row5_col1, #T_faea8_row5_col2, #T_faea8_row5_col3, #T_faea8_row5_col4, #T_faea8_row5_col5, #T_faea8_row5_col6, #T_faea8_row5_col7, #T_faea8_row5_col8, #T_faea8_row5_col9, #T_faea8_row6_col0, #T_faea8_row6_col1, #T_faea8_row6_col2, #T_faea8_row6_col3, #T_faea8_row6_col4, #T_faea8_row6_col5, #T_faea8_row6_col6, #T_faea8_row6_col7, #T_faea8_row6_col8, #T_faea8_row6_col9, #T_faea8_row7_col0, #T_faea8_row7_col1, #T_faea8_row7_col2, #T_faea8_row7_col3, #T_faea8_row7_col4, #T_faea8_row7_col5, #T_faea8_row7_col6, #T_faea8_row7_col7, #T_faea8_row7_col8, #T_faea8_row7_col9, #T_faea8_row8_col0, #T_faea8_row8_col1, #T_faea8_row8_col2, #T_faea8_row8_col3, #T_faea8_row8_col4, #T_faea8_row8_col5, #T_faea8_row8_col6, #T_faea8_row8_col7, #T_faea8_row8_col8, #T_faea8_row8_col9, #T_faea8_row9_col0, #T_faea8_row9_col1, #T_faea8_row9_col2, #T_faea8_row9_col3, #T_faea8_row9_col4, #T_faea8_row9_col5, #T_faea8_row9_col6, #T_faea8_row9_col7, #T_faea8_row9_col8, #T_faea8_row9_col9, #T_faea8_row10_col0, #T_faea8_row10_col1, #T_faea8_row10_col2, #T_faea8_row10_col3, #T_faea8_row10_col4, #T_faea8_row10_col5, #T_faea8_row10_col6, #T_faea8_row10_col7, #T_faea8_row10_col8, #T_faea8_row10_col9, #T_faea8_row11_col0, #T_faea8_row11_col1, #T_faea8_row11_col2, #T_faea8_row11_col3, #T_faea8_row11_col4, #T_faea8_row11_col5, #T_faea8_row11_col6, #T_faea8_row11_col7, #T_faea8_row11_col8, #T_faea8_row11_col9, #T_faea8_row12_col0, #T_faea8_row12_col1, #T_faea8_row12_col2, #T_faea8_row12_col3, #T_faea8_row12_col4, #T_faea8_row12_col5, #T_faea8_row12_col6, #T_faea8_row12_col7, #T_faea8_row12_col8, #T_faea8_row12_col9, #T_faea8_row13_col0, #T_faea8_row13_col1, #T_faea8_row13_col2, #T_faea8_row13_col3, #T_faea8_row13_col4, #T_faea8_row13_col5, #T_faea8_row13_col6, #T_faea8_row13_col7, #T_faea8_row13_col8, #T_faea8_row13_col9, #T_faea8_row14_col0, #T_faea8_row14_col1, #T_faea8_row14_col2, #T_faea8_row14_col3, #T_faea8_row14_col4, #T_faea8_row14_col5, #T_faea8_row14_col6, #T_faea8_row14_col7, #T_faea8_row14_col8, #T_faea8_row14_col9, #T_faea8_row15_col0, #T_faea8_row15_col1, #T_faea8_row15_col2, #T_faea8_row15_col3, #T_faea8_row15_col4, #T_faea8_row15_col5, #T_faea8_row15_col6, #T_faea8_row15_col7, #T_faea8_row15_col8, #T_faea8_row15_col9, #T_faea8_row16_col0, #T_faea8_row16_col1, #T_faea8_row16_col2, #T_faea8_row16_col3, #T_faea8_row16_col4, #T_faea8_row16_col5, #T_faea8_row16_col6, #T_faea8_row16_col7, #T_faea8_row16_col8, #T_faea8_row16_col9, #T_faea8_row17_col0, #T_faea8_row17_col1, #T_faea8_row17_col2, #T_faea8_row17_col3, #T_faea8_row17_col4, #T_faea8_row17_col5, #T_faea8_row17_col6, #T_faea8_row17_col7, #T_faea8_row17_col8, #T_faea8_row17_col9, #T_faea8_row18_col0, #T_faea8_row18_col1, #T_faea8_row18_col2, #T_faea8_row18_col3, #T_faea8_row18_col4, #T_faea8_row18_col5, #T_faea8_row18_col6, #T_faea8_row18_col7, #T_faea8_row18_col8, #T_faea8_row18_col9, #T_faea8_row19_col0, #T_faea8_row19_col1, #T_faea8_row19_col2, #T_faea8_row19_col3, #T_faea8_row19_col4, #T_fa ...

# %% [markdown]
# ### Wallet APIs

# %% [markdown]
# Supported Chains

# %%
url = "https://public-api.birdeye.so/v1/wallet/list_supported_chain"

headers = {
    "accept": "application/json",
    "X-API-KEY": API_Key
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true,"data":["solana","ethereum","arbitrum","avalanche","bsc","optimism","polygon","base","zksync"]}

# %% [markdown]
# Wallet Portfolio Multichain

# %%
wallet = d.sol_wallet
multichain = "sol,ethereum,bsc"

url = f"https://public-api.birdeye.so/v1/wallet/multichain_token_list?wallet={wallet}"

headers = {
    "accept": "application/json",
    "x-chains": multichain,
    "X-API-KEY": API_Key
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = json.loads(response.text)
    if 'data' in data:
        all_tokens = []
        for chain, chain_data in data['data'].items():
            if isinstance(chain_data, list):
                for token in chain_data:
                    if isinstance(token, dict):
                        token['chain'] = chain
                        all_tokens.append(token)
            elif isinstance(chain_data, dict):
                chain_data['chain'] = chain
                all_tokens.append(chain_data)
        
        if all_tokens:
            df = pd.DataFrame(all_tokens)
            
            # Reorder columns to have 'chain' first
            columns = ['chain'] + [col for col in df.columns if col != 'chain']
            df = df[columns]
            
            # Style the DataFrame
            styled_df = df.style.set_properties(**{
                'white-space': 'nowrap',
                'font-family': 'monospace',
                'font-size': '10pt',
                'text-align': 'right'
            }).set_table_styles([
                {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
                {'selector': 'td', 'props': [('padding', '5px')]}
            ]).format({
                'price': '${:.8f}',
                'value': '${:.2f}',
                'amount': '{:.8f}'
            })
            
            # Display the styled DataFrame
            display(HTML("<h3>Multichain Wallet Token List</h3>"))
            display(HTML(styled_df.to_html()))
        else:
            print("No tokens found in the wallet.")
    else:
        print("Unexpected response structure. 'data' key not found.")
        print(json.dumps(data, indent=2))
else:
    print(f"Request failed with status code: {response.status_code}")
    print(response.text)
# Out:
# <h3>Multichain Wallet Token List</h3>
# <style type="text/css">
# #T_c7d34 th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_c7d34 td {
#   padding: 5px;
# }
# #T_c7d34_row0_col0, #T_c7d34_row0_col1, #T_c7d34_row0_col2, #T_c7d34_row0_col3, #T_c7d34_row0_col4, #T_c7d34_row0_col5, #T_c7d34_row0_col6, #T_c7d34_row0_col7, #T_c7d34_row0_col8, #T_c7d34_row0_col9, #T_c7d34_row0_col10, #T_c7d34_row0_col11, #T_c7d34_row1_col0, #T_c7d34_row1_col1, #T_c7d34_row1_col2, #T_c7d34_row1_col3, #T_c7d34_row1_col4, #T_c7d34_row1_col5, #T_c7d34_row1_col6, #T_c7d34_row1_col7, #T_c7d34_row1_col8, #T_c7d34_row1_col9, #T_c7d34_row1_col10, #T_c7d34_row1_col11 {
#   white-space: nowrap;
#   font-family: monospace;
#   font-size: 10pt;
#   text-align: right;
# }
# </style>
# <table id="T_c7d34">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7d34_level0_col0" class="col_heading level0 col0" >chain</th>
#       <th id="T_c7d34_level0_col1" class="col_heading level0 col1" >address</th>
#       <th id="T_c7d34_level0_col2" class="col_heading level0 col2" >decimals</th>
#       <th id="T_c7d34_level0_col3" class="col_heading level0 col3" >balance</th>
#       <th id="T_c7d34_level0_col4" class="col_heading level0 col4" >uiAmount</th>
#       <th id="T_c7d34_level0_col5" class="col_heading level0 col5" >chainId</th>
#       <th id="T_c7d34_level0_col6" class="col_heading level0 col6" >name</th>
#       <th id="T_c7d34_level0_col7" class="col_heading level0 col7" >symbol</th>
#       <th id="T_c7d34_level0_col8" class="col_heading level0 col8" >logoURI</th>
#       <th id="T_c7d34_level0_col9" class="col_heading level0 col9" >priceUsd</th>
#       <th id="T_c7d34_level0_col10" class="col_heading level0 col10" >valueUsd</th>
#       <th id="T_c7d34_level0_col11" class="col_heading level0 col11" >icon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7d34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7d34_row0_col0" class="data row0 col0" >items</td>
#       <td id="T_c7d34_row0_col1" class="data row0 col1" >So11111111111111111111111111111111111111111</td>
#       <td id="T_c7d34_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_c7d34_row0_col3" class="data row0 col3" >41407930</td>
#       <td id="T_c7d34_row0_col4" class="data row0 col4" >0.041408</td>
#       <td id="T_c7d34_row0_col5" class="data row0 col5" >solana</td>
#       <td id="T_c7d34_row0_col6" class="data row0 col6" >SOL</td>
#       <td id="T_c7d34_row0_col7" class="data row0 col7" >SOL</td>
#       <td id="T_c7d34_row0_col8" class="data row0 col8" >https://img.fotofolio.xyz/?w=128&h=128&url=https%3A%2F%2Fraw.githubusercontent.com%2Fsolana-labs%2Ftoken-list%2Fmain%2Fassets%2Fmainnet%2FSo11111111111111111111111111111111111111112%2Flogo.png</td>
#       <td id="T_c7d34_row0_col9" class="data row0 col9" >153.266047</td>
#       <td id="T_c7d34_row0_col10" class="data row0 col10" >6.346430</td>
#       <td id="T_c7d34_row0_col11" class="data row0 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c7d34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7d34_row1_col0" class="data row1 col0" >items</td>
#       <td id="T_c7d34_row1_col1" class="data row1 col1" >EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm</td>
#       <td id="T_c7d34_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_c7d34_row1_col3" class="data row1 col3" >871041</td>
#       <td id="T_c7d34_row1_col4" class="data row1 col4" >0.871041</td>
#       <td id="T_c7d34_row1_col5" class="data row1 col5" >solana</td>
#       <td id="T_c7d34_row1_col6" class="data row1 col6" >dogwifhat</td>
#       <td id="T_c7d34_row1_col7" class="data row1 col7" >$WIF</td>
#       <td id="T_c7d34_row1_col8" class="data row1 col8" >https://img.fotofolio.xyz/?w=128&h=128&url=https%3A%2F%2Fbafkreibk3covs5ltyqxa272uodhculbr6kea6betidfwy3ajsav2vjzyum.ipfs.nftstorage.link</td>
#       <td id="T_c7d34_row1_col9" class="data row1 col9" >2.626129</td>
#       <td id="T_c7d34_row1_col10" class="data row1 col10" >2.287466</td>
#       <td id="T_c7d34_row1_col11" class="data row1 col11" >https://img.fotofolio.xyz/?w=128&h=128&url=https%3A%2F%2Fbafkreibk3covs5ltyqxa272uodhculbr6kea6betidfwy3ajsav2vjzyum.ipfs.nftstorage.link</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Wallet Transaction History (Multichain)

# %%
url = f"https://public-api.birdeye.so/v1/wallet/multichain_tx_list?wallet={wallet}"

headers = {
    "accept": "application/json",
    "x-chains": multichain,
    "X-API-KEY": API_Key
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = json.loads(response.text)
    if 'data' in data:
        all_transactions = []
        for chain, chain_data in data['data'].items():
            for tx in chain_data:
                tx['chain'] = chain
                all_transactions.append(tx)
        
        if all_transactions:
            df = pd.DataFrame(all_transactions)
            
            # Convert blockTime to datetime
            df['datetime'] = pd.to_datetime(df['blockTime'])
            
            # Reorder columns to have 'chain' and 'datetime' first
            columns = ['chain', 'datetime'] + [col for col in df.columns if col not in ['chain', 'datetime', 'blockTime']]
            df = df[columns]
            
            # Style the DataFrame
            styled_df = df.style.set_properties(**{
                'white-space': 'nowrap',
                'font-family': 'monospace',
                'font-size': '10pt',
                'text-align': 'right'
            }).set_table_styles([
                {'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]},
                {'selector': 'td', 'props': [('padding', '5px')]}
            ]).format({
                'datetime': lambda x: x.strftime('%Y-%m-%d %H:%M:%S'),
                'fee': '{:,.0f}',
                'blockNumber': '{:,}'
            })
            
            # Display the styled DataFrame
            display(HTML(f"<h3>Multichain Wallet Transaction List (Total: {len(df)} transactions)</h3>"))
            display(HTML(styled_df.to_html()))
        else:
            print("No transactions found for the wallet.")
    else:
        print("Unexpected response structure. 'data' key not found.")
        print(json.dumps(data, indent=2))
else:
    print(f"Request failed with status code: {response.status_code}")
    print(response.text)
# Out:
# <h3>Multichain Wallet Transaction List (Total: 21 transactions)</h3>
# <style type="text/css">
# #T_698c2 th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_698c2 td {
#   padding: 5px;
# }
# #T_698c2_row0_col0, #T_698c2_row0_col1, #T_698c2_row0_col2, #T_698c2_row0_col3, #T_698c2_row0_col4, #T_698c2_row0_col5, #T_698c2_row0_col6, #T_698c2_row0_col7, #T_698c2_row0_col8, #T_698c2_row0_col9, #T_698c2_row0_col10, #T_698c2_row1_col0, #T_698c2_row1_col1, #T_698c2_row1_col2, #T_698c2_row1_col3, #T_698c2_row1_col4, #T_698c2_row1_col5, #T_698c2_row1_col6, #T_698c2_row1_col7, #T_698c2_row1_col8, #T_698c2_row1_col9, #T_698c2_row1_col10, #T_698c2_row2_col0, #T_698c2_row2_col1, #T_698c2_row2_col2, #T_698c2_row2_col3, #T_698c2_row2_col4, #T_698c2_row2_col5, #T_698c2_row2_col6, #T_698c2_row2_col7, #T_698c2_row2_col8, #T_698c2_row2_col9, #T_698c2_row2_col10, #T_698c2_row3_col0, #T_698c2_row3_col1, #T_698c2_row3_col2, #T_698c2_row3_col3, #T_698c2_row3_col4, #T_698c2_row3_col5, #T_698c2_row3_col6, #T_698c2_row3_col7, #T_698c2_row3_col8, #T_698c2_row3_col9, #T_698c2_row3_col10, #T_698c2_row4_col0, #T_698c2_row4_col1, #T_698c2_row4_col2, #T_698c2_row4_col3, #T_698c2_row4_col4, #T_698c2_row4_col5, #T_698c2_row4_col6, #T_698c2_row4_col7, #T_698c2_row4_col8, #T_698c2_row4_col9, #T_698c2_row4_col10, #T_698c2_row5_col0, #T_698c2_row5_col1, #T_698c2_row5_col2, #T_698c2_row5_col3, #T_698c2_row5_col4, #T_698c2_row5_col5, #T_698c2_row5_col6, #T_698c2_row5_col7, #T_698c2_row5_col8, #T_698c2_row5_col9, #T_698c2_row5_col10, #T_698c2_row6_col0, #T_698c2_row6_col1, #T_698c2_row6_col2, #T_698c2_row6_col3, #T_698c2_row6_col4, #T_698c2_row6_col5, #T_698c2_row6_col6, #T_698c2_row6_col7, #T_698c2_row6_col8, #T_698c2_row6_col9, #T_698c2_row6_col10, #T_698c2_row7_col0, #T_698c2_row7_col1, #T_698c2_row7_col2, #T_698c2_row7_col3, #T_698c2_row7_col4, #T_698c2_row7_col5, #T_698c2_row7_col6, #T_698c2_row7_col7, #T_698c2_row7_col8, #T_698c2_row7_col9, #T_698c2_row7_col10, #T_698c2_row8_col0, #T_698c2_row8_col1, #T_698c2_row8_col2, #T_698c2_row8_col3, #T_698c2_row8_col4, #T_698c2_row8_col5, #T_698c2_row8_col6, #T_698c2_row8_col7, #T_698c2_row8_col8, #T_698c2_row8_col9, #T_698c2_row8_col10, #T_698c2_row9_col0, #T_698c2_row9_col1, #T_698c2_row9_col2, #T_698c2_row9_col3, #T_698c2_row9_col4, #T_698c2_row9_col5, #T_698c2_row9_col6, #T_698c2_row9_col7, #T_698c2_row9_col8, #T_698c2_row9_col9, #T_698c2_row9_col10, #T_698c2_row10_col0, #T_698c2_row10_col1, #T_698c2_row10_col2, #T_698c2_row10_col3, #T_698c2_row10_col4, #T_698c2_row10_col5, #T_698c2_row10_col6, #T_698c2_row10_col7, #T_698c2_row10_col8, #T_698c2_row10_col9, #T_698c2_row10_col10, #T_698c2_row11_col0, #T_698c2_row11_col1, #T_698c2_row11_col2, #T_698c2_row11_col3, #T_698c2_row11_col4, #T_698c2_row11_col5, #T_698c2_row11_col6, #T_698c2_row11_col7, #T_698c2_row11_col8, #T_698c2_row11_col9, #T_698c2_row11_col10, #T_698c2_row12_col0, #T_698c2_row12_col1, #T_698c2_row12_col2, #T_698c2_row12_col3, #T_698c2_row12_col4, #T_698c2_row12_col5, #T_698c2_row12_col6, #T_698c2_row12_col7, #T_698c2_row12_col8, #T_698c2_row12_col9, #T_698c2_row12_col10, #T_698c2_row13_col0, #T_698c2_row13_col1, #T_698c2_row13_col2, #T_698c2_row13_col3, #T_698c2_row13_col4, #T_698c2_row13_col5, #T_698c2_row13_col6, #T_698c2_row13_col7, #T_698c2_row13_col8, #T_698c2_row13_col9, #T_698c2_row13_col10, #T_698c2_row14_col0, #T_698c2_row14_col1, #T_698c2_row14_col2, #T_698c2_row14_col3, #T_698c2_row14_col4, #T_698c2_row14_col5, #T_698c2_row14_col6, #T_698c2_row14_col7, #T_698c2_row14_col8, #T_698c2_row14_col9, #T_698c2_row14_col10, #T_698c2_row15_col0, #T_698c2_row15_col1, #T_698c2_row15_col2, #T_698c2_row15_col3, #T_698c2_row15_col4, #T_698c2_row15_col5, #T_698c2_row15_col6, #T_698c2_row15_col7, #T_698c2_row15_col8, #T_698c2_row15_col9, #T_698c2_row15_col10, #T_698c2_row16_col0, #T_698c2_row16_col1, #T_698c2_row16_col2, #T_698c2_row16_col3, #T_698c2_row16_col4, #T_698c2_row16_col5, #T_698c2_row16_col6, #T_698c2_row16_col7, #T_698c2_row16_col8, #T_698c2_row16_col9, #T_698c2_row16_col10, #T_698c2_row17_col0, #T_698c2_row17_col1, #T_698c2_row17_col2, #T_698c2_row17_col3, #T_698c2_row17_col4, #T_698c2_row17_col5, #T_698c2_row17_col6, #T_698c2_row17_col7 ...
#   white-space: nowrap;
#   font-family: monospace;
#   font-size: 10pt;
#   text-align: right;
# }
# </style>
# <table id="T_698c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_698c2_level0_col0" class="col_heading level0 col0" >chain</th>
#       <th id="T_698c2_level0_col1" class="col_heading level0 col1" >datetime</th>
#       <th id="T_698c2_level0_col2" class="col_heading level0 col2" >txHash</th>
#       <th id="T_698c2_level0_col3" class="col_heading level0 col3" >blockNumber</th>
#       <th id="T_698c2_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_698c2_level0_col5" class="col_heading level0 col5" >from</th>
#       <th id="T_698c2_level0_col6" class="col_heading level0 col6" >to</th>
#       <th id="T_698c2_level0_col7" class="col_heading level0 col7" >fee</th>
#       <th id="T_698c2_level0_col8" class="col_heading level0 col8" >mainAction</th>
#       <th id="T_698c2_level0_col9" class="col_heading level0 col9" >balanceChange</th>
#       <th id="T_698c2_level0_col10" class="col_heading level0 col10" >contractLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_698c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_698c2_row0_col0" class="data row0 col0" >solana</td>
#       <td id="T_698c2_row0_col1" class="data row0 col1" >2024-10-17 03:09:33</td>
#       <td id="T_698c2_row0_col2" class="data row0 col2" >3yYC786JFvEuPtmeqALQ5MTGmD4s8SMsHkMAw1vcw2hzuBcQCcSb2e9zVkgFDVV41mFSiS1WsFZduvGtEBUEH1DW</td>
#       <td id="T_698c2_row0_col3" class="data row0 col3" >296,057,452</td>
#       <td id="T_698c2_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_698c2_row0_col5" class="data row0 col5" >5Hr7wZg7oBpVhH5nngRqzr5W7ZFUfCsfEhbziZJak7fr</td>
#       <td id="T_698c2_row0_col6" class="data row0 col6" >11111111111111111111111111111111</td>
#       <td id="T_698c2_row0_col7" class="data row0 col7" >6,400</td>
#       <td id="T_698c2_row0_col8" class="data row0 col8" >received</td>
#       <td id="T_698c2_row0_col9" class="data row0 col9" >[{'amount': 1, 'symbol': 'SOL', 'name': 'Wrapped SOL', 'decimals': 9, 'address': 'So11111111111111111111111111111111111111112', 'logoURI': 'https://wsrv.nl/?w=128&h=128&url=https%3A%2F%2Fraw.githubusercontent.com%2Fsolana-labs%2Ftoken-list%2Fmain%2Fassets%2Fmainnet%2FSo11111111111111111111111111111111111111112%2Flogo.png'}]</td>
#       <td id="T_698c2_row0_col10" class="data row0 col10" >{'address': '11111111111111111111111111111111', 'name': 'System Program', 'metadata': {'icon': ''}}</td>
#     </tr>
#     <tr>
#       <th id="T_698c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_698c2_row1_col0" class="data row1 col0" >solana</td>
#       <td id="T_698c2_row1_col1" class="data row1 col1" >2024-10-16 03:09:12</td>
#       <td id="T_698c2_row1_col2" class="data row1 col2" >258wURNkBgZ9196NeTMMisgtymkiLBzeU5ivNWYZFbzf1mqyDBKmsizanivBRBPYuyYGSU5ZbH64nyQu4DKJ5Xdw</td>
#       <td id="T_698c2_row1_col3" class="data row1 col3" >295,872,751</td>
#       <td id="T_698c2_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_698c2_row1_col5" class="data row1 col
