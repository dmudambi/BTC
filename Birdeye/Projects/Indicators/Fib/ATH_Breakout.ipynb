# %%
import os
import sys
import json
from datetime import datetime
import subprocess
import pandas as pd
import plotly.graph_objects as go
current_dir = os.getcwd()
root_dir = os.path.abspath(os.path.join(current_dir, '..', '..', '..', '..'))
sys.path.append(root_dir)
import Birdeye.Basics.ATH_Breakout_Master as ATH_Breakout_Master
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# Specify the path to the Python file you want to run
python_file_path = 'Dataset_ATH_Breakout.py'

# Run the Python file
subprocess.run(['python', python_file_path])
# Out:
# {"success":true,"data":["solana","ethereum","arbitrum","avalanche","bsc","optimism","polygon","base","zksync"]}
#
# --------------------------------
#
# Running on: solana
#
# --------------------------------
#
# NEW TOKEN FILTERS:
#
# Min Liquidity: 30K
# Max Liquidity: 1.00Mil
# Min Market Cap: 500K
# Max Market Cap: 50.00Mil
# Filtering New Tokens for: 2 days, 23 hours, 0 minutes back
# Token Launch Liquidity Filter: 30K
#
# --------------------------------
#
#  Collecting New Token Listings...
#
# --------------------------------
#
# https://dexscreener.com/solana/D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe - Market Cap: 46.41Mil
# https://dexscreener.com/solana/9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 - Market Cap: 40.26Mil
# https://dexscreener.com/solana/6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY - Market Cap: 23.06Mil
# https://dexscreener.com/solana/8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump - Market Cap: 14.57Mil
# https://dexscreener.com/solana/FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump - Market Cap: 9.57Mil
# https://dexscreener.com/solana/ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi - Market Cap: 5.69Mil
# https://dexscreener.com/solana/47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump - Market Cap: 5.68Mil
# https://dexscreener.com/solana/EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump - Market Cap: 5.61Mil
# https://dexscreener.com/solana/Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump - Market Cap: 5.47Mil
# https://dexscreener.com/solana/2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump - Market Cap: 4.82Mil
# https://dexscreener.com/solana/9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb - Market Cap: 4.71Mil
# https://dexscreener.com/solana/82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd - Market Cap: 4.61Mil
# https://dexscreener.com/solana/bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump - Market Cap: 4.47Mil
# https://dexscreener.com/solana/7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump - Market Cap: 4.31Mil
# https://dexscreener.com/solana/G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump - Market Cap: 3.82Mil
# https://dexscreener.com/solana/Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump - Market Cap: 3.06Mil
# https://dexscreener.com/solana/4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump - Market Cap: 3.00Mil
# https://dexscreener.com/solana/7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg - Market Cap: 2.86Mil
# https://dexscreener.com/solana/61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump - Market Cap: 2.43Mil
# https://dexscreener.com/solana/FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump - Market Cap: 2.23Mil
# https://dexscreener.com/solana/84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump - Market Cap: 2.22Mil
# https://dexscreener.com/solana/7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump - Market Cap: 2.18Mil
# https://dexscreener.com/solana/7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj - Market Cap: 2.15Mil
# https://dexscreener.com/solana/qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump - Market Cap: 2.05Mil
# https://dexscreener.com/solana/2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM - Market Cap: 1.98Mil
# https://dexscreener.com/solana/EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 - Market Cap: 1.94Mil
# https://dexscreener.com/solana/FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump - Market Cap: 1.84Mil
# https://dexscreener.com/solana/5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump - Market Cap: 1.77Mil
# https://dexscreener.com/solana/7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ - Market Cap: 1.76Mil
# https://dexscreener.com/solana/3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 - Market Cap: 1.69Mil
# https://dexscreener.com/solana/BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump - Market Cap: 1.59Mil
# https://dexscreener.com/solana/EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump - Market Cap: 1.53Mil
# https://dexscreener.com/solana/CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump - Market Cap: 1.50Mil
# https://dexscreener.com/solana/EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump - Market Cap: 1.37Mil
# https://dexscreener.com/solana/EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump - Market Cap: 1.37Mil
# https://dexscreener.com/solana/AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump - Market Cap: 1.32Mil
# https://dexscreener.com/solana/6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq - Market Cap: 1.24Mil
# https://dexscreener.com/solana/BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 - Market Cap: 1.15Mil
# https://dexscreener.com/solana/8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump - Market Cap: 1.11Mil
# https://dexscreener.com/solana/6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump - Market Cap: 1.09Mil
# https://dexscreener.com/solana/A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump - Market Cap: 1.07Mil
# https://dexscreener.com/solana/3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump - Market Cap: 980K
# https://dexscreener.com/solana/4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump - Market Cap: 940K
# https://dexscreener.com/solana/5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump - Market Cap: 863K
# https://dexscreener.com/solana/BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump - Market Cap: 786K
# https://dexscreener.com/solana/4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump - Market Cap: 775K
# https://dexscreener.com/solana/B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump - Market Cap: 732K
# https://dexscreener.com/solana/5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA - Market Cap: 700K
# https://dexscreener.com/solana/8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP - Market Cap: 671K
# https://dexscreener.com/solana/8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump - Market Cap: 654K
# https://dexscreener.com/solana/HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV - Market Cap: 639K
# https://dexscreener.com/solana/3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump - Market Cap: 636K
# https://dexscreener.com/solana/A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump - Market Cap: 635K
# https://dexscreener.com/solana/ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump - Market Cap: 624K
# https://dexscreener.com/solana/73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump - Market Cap: 589K
# https://dexscreener.com/solana/FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump - Market Cap: 558K
# https://dexscreener.com/solana/HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump - Market Cap: 554K
# https://dexscreener.com/solana/HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd - Market Cap: 549K
# https://dexscreener.com/solana/HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump - Market Cap: 548K
# https://dexscreener.com/solana/7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump - Market Cap: 527K
# https://dexscreener.com/solana/Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb - Market Cap: 519K
# https://dexscreener.com/solana/96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump - Market Cap: 518K
#
# Token summary data saved to: Data/New_Token_Data/2024_11_12/Token_Summary/2024_Nov_12_0623AM/new_tokens_mc_added_filtered_0.5M-50.0M_2d_23h_0m.csv
#
# Number of Tokens Filtered: 62
#
# --------------------------------
#
# All Token summary data saved to: Data/New_Token_Data/2024_11_12/Token_Summary/2024_Nov_12_0623AM/new_tokens_mc_added_filtered_0.5M-50.0M_2d_23h_0m.csv
#
# --------------------------------
#
# Timeframes being used to retrieve OHLCV data: 1m, 5m, 15m, 1H
#
# --------------------------------
#
#
# Successfully retrieved 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump - 1m data.
#
# Successfully retrieved 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump - 5m data.
#
# Successfully retrieved 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump - 15m data.
#
# Successfully retrieved 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump - 1H data.
# OHLCV data retrieval and storage completed for 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump (1m).
# OHLCV data retrieval and storage completed for 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump (5m).
# OHLCV data retrieval and storage completed for 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump (15m).
# OHLCV data retrieval and storage completed for 8GFdFMyYJgRNnR4zGrzcVvK1PdxF4bhrcuvbtv3Cpump (1H).
#
# Successfully retrieved 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump - 1m data.
#
# Successfully retrieved 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump - 5m data.
#
# Successfully retrieved 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump - 15m data.
#
# Successfully retrieved 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump - 1H data.
# OHLCV data retrieval and storage completed for 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump (1m).
# OHLCV data retrieval and storage completed for 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump (5m).
# OHLCV data retrieval and storage completed for 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump (15m).
# OHLCV data retrieval and storage completed for 73UdJevxaNKXARgkvPHQGKuv8HCZARszuKW2LTL3pump (1H).
#
# Successfully retrieved Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb - 1m data.
#
# Successfully retrieved Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb - 5m data.
#
# Successfully retrieved Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb - 15m data.
#
# Successfully retrieved Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb - 1H data.
# OHLCV data retrieval and storage completed for Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb (1m).
# OHLCV data retrieval and storage completed for Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb (5m).
# OHLCV data retrieval and storage completed for Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb (15m).
# OHLCV data retrieval and storage completed for Gaq4vWNWQiMyVtrXGHSMVMbLP2Cd8CntxQY5kh8SGTUb (1H).
#
# Successfully retrieved 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump - 1m data.
#
# Successfully retrieved 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump - 5m data.
#
# Successfully retrieved 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump - 15m data.
#
# Successfully retrieved 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump - 1H data.
# OHLCV data retrieval and storage completed for 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump (1m).
# OHLCV data retrieval and storage completed for 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump (5m).
# OHLCV data retrieval and storage completed for 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump (15m).
# OHLCV data retrieval and storage completed for 8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvpump (1H).
#
# Successfully retrieved FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump - 1m data.
#
# Successfully retrieved FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump - 5m data.
#
# Successfully retrieved FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump - 15m data.
#
# Successfully retrieved FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump - 1H data.
# OHLCV data retrieval and storage completed for FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump (1m).
# OHLCV data retrieval and storage completed for FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump (5m).
# OHLCV data retrieval and storage completed for FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump (15m).
# OHLCV data retrieval and storage completed for FuQASH8ps9NPeDu4h3rVtMBygKYoSiSTZ4uSiA5tpump (1H).
#
# Successfully retrieved 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd - 1m data.
#
# Successfully retrieved 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd - 5m data.
#
# Successfully retrieved 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd - 15m data.
#
# Successfully retrieved 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd - 1H data.
# OHLCV data retrieval and storage completed for 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd (1m).
# OHLCV data retrieval and storage completed for 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd (5m).
# OHLCV data retrieval and storage completed for 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd (15m).
# OHLCV data retrieval and storage completed for 82muMHDFVwG3c5iTxhWYw3q75G8nHyTqLpdKwMQTFwQd (1H).
#
# Successfully retrieved 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump - 1m data.
#
# Successfully retrieved 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump - 5m data.
#
# Successfully retrieved 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump - 15m data.
#
# Successfully retrieved 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump - 1H data.
# OHLCV data retrieval and storage completed for 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump (1m).
# OHLCV data retrieval and storage completed for 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump (5m).
# OHLCV data retrieval and storage completed for 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump (15m).
# OHLCV data retrieval and storage completed for 5h5YCbybHMpVj378FrxrypY9eXKoy92Vpw9xyru1pump (1H).
#
# Successfully retrieved 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg - 1m data.
#
# Successfully retrieved 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg - 5m data.
#
# Successfully retrieved 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg - 15m data.
#
# Successfully retrieved 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg - 1H data.
# OHLCV data retrieval and storage completed for 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg (1m).
# OHLCV data retrieval and storage completed for 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg (5m).
# OHLCV data retrieval and storage completed for 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg (15m).
# OHLCV data retrieval and storage completed for 7MJuVYPNDxo3xh6U5kGVsrSxqRPaLzGNYunUUxGKY6kg (1H).
#
# Successfully retrieved ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi - 1m data.
#
# Successfully retrieved ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi - 5m data.
#
# Successfully retrieved ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi - 15m data.
#
# Successfully retrieved ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi - 1H data.
# OHLCV data retrieval and storage completed for ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi (1m).
# OHLCV data retrieval and storage completed for ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi (5m).
# OHLCV data retrieval and storage completed for ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi (15m).
# OHLCV data retrieval and storage completed for ABgHHrBxAYC5aZUXTUS6ERxFTL8KeNjtbp1K1G3SXoQi (1H).
#
# Successfully retrieved EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump - 1m data.
#
# Successfully retrieved EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump - 5m data.
#
# Successfully retrieved EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump - 15m data.
#
# Successfully retrieved EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump - 1H data.
# OHLCV data retrieval and storage completed for EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump (1m).
# OHLCV data retrieval and storage completed for EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump (5m).
# OHLCV data retrieval and storage completed for EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump (15m).
# OHLCV data retrieval and storage completed for EmhVWGUa2Q9PN4QjzFjvuVyzFKg4s3ERwjKR9dQDpump (1H).
#
# Successfully retrieved HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd - 1m data.
#
# Successfully retrieved HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd - 5m data.
#
# Successfully retrieved HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd - 15m data.
#
# Successfully retrieved HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd - 1H data.
# OHLCV data retrieval and storage completed for HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd (1m).
# OHLCV data retrieval and storage completed for HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd (5m).
# OHLCV data retrieval and storage completed for HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd (15m).
# OHLCV data retrieval and storage completed for HLH5Qn92L3L9Ebm96Sa8rygepe4WaEQGotpqgUeSG9Jd (1H).
#
# Successfully retrieved FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump - 1m data.
#
# Successfully retrieved FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump - 5m data.
#
# Successfully retrieved FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump - 15m data.
#
# Successfully retrieved FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump - 1H data.
# OHLCV data retrieval and storage completed for FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump (1m).
# OHLCV data retrieval and storage completed for FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump (5m).
# OHLCV data retrieval and storage completed for FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump (15m).
# OHLCV data retrieval and storage completed for FjTJCCQpLU4fpH58mN1bTQXiQsjJVYai3QYFjYqYpump (1H).
#
# Successfully retrieved 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump - 1m data.
#
# Successfully retrieved 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump - 5m data.
#
# Successfully retrieved 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump - 15m data.
#
# Successfully retrieved 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump - 1H data.
# OHLCV data retrieval and storage completed for 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump (1m).
# OHLCV data retrieval and storage completed for 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump (5m).
# OHLCV data retrieval and storage completed for 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump (15m).
# OHLCV data retrieval and storage completed for 8467ssuj6Gkw15ABv6BvxJAKnGJALXJu6dxDxt4upump (1H).
#
# Successfully retrieved 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump - 1m data.
#
# Successfully retrieved 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump - 5m data.
#
# Successfully retrieved 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump - 15m data.
#
# Successfully retrieved 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump - 1H data.
# OHLCV data retrieval and storage completed for 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump (1m).
# OHLCV data retrieval and storage completed for 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump (5m).
# OHLCV data retrieval and storage completed for 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump (15m).
# OHLCV data retrieval and storage completed for 5E643BWj8k71yuJqn9n2QCg589bphjeRzEcgGP2xpump (1H).
#
# Successfully retrieved 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump - 1m data.
#
# Successfully retrieved 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump - 5m data.
#
# Successfully retrieved 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump - 15m data.
#
# Successfully retrieved 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump - 1H data.
# OHLCV data retrieval and storage completed for 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump (1m).
# OHLCV data retrieval and storage completed for 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump (5m).
# OHLCV data retrieval and storage completed for 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump (15m).
# OHLCV data retrieval and storage completed for 6QciU9YcYiCEbxPKWZT6UfyWGfzqiqGjhSn3F7Nvpump (1H).
#
# Successfully retrieved Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump - 1m data.
#
# Successfully retrieved Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump - 5m data.
#
# Successfully retrieved Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump - 15m data.
#
# Successfully retrieved Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump - 1H data.
# OHLCV data retrieval and storage completed for Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump (1m).
# OHLCV data retrieval and storage completed for Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump (5m).
# OHLCV data retrieval and storage completed for Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump (15m).
# OHLCV data retrieval and storage completed for Br7A4zEMxc2YXC8MZs2y3R8uqsK48ZPEsHxP9rXXpump (1H).
#
# Successfully retrieved qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump - 1m data.
#
# Successfully retrieved qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump - 5m data.
#
# Successfully retrieved qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump - 15m data.
#
# Successfully retrieved qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump - 1H data.
# OHLCV data retrieval and storage completed for qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump (1m).
# OHLCV data retrieval and storage completed for qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump (5m).
# OHLCV data retrieval and storage completed for qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump (15m).
# OHLCV data retrieval and storage completed for qfAV15JCvquMYpjGGkhQGr8x2zTiw14pCpUCjXLpump (1H).
#
# Successfully retrieved 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY - 1m data.
#
# Successfully retrieved 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY - 5m data.
#
# Successfully retrieved 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY - 15m data.
#
# Successfully retrieved 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY - 1H data.
# OHLCV data retrieval and storage completed for 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY (1m).
# OHLCV data retrieval and storage completed for 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY (5m).
# OHLCV data retrieval and storage completed for 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY (15m).
# OHLCV data retrieval and storage completed for 6yrFPZEkSQD46TpLEBgtbuuaghGxTkW2o2cyrp5t2rxY (1H).
#
# Successfully retrieved 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 - 1m data.
#
# Successfully retrieved 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 - 5m data.
#
# Successfully retrieved 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 - 15m data.
#
# Successfully retrieved 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 - 1H data.
# OHLCV data retrieval and storage completed for 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 (1m).
# OHLCV data retrieval and storage completed for 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 (5m).
# OHLCV data retrieval and storage completed for 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 (15m).
# OHLCV data retrieval and storage completed for 9DzEXkhGdtrdp1CmWwSn5bSQ6j7m8PFDc6dWSf4YCni1 (1H).
#
# Successfully retrieved 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq - 1m data.
#
# Successfully retrieved 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq - 5m data.
#
# Successfully retrieved 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq - 15m data.
#
# Successfully retrieved 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq - 1H data.
# OHLCV data retrieval and storage completed for 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq (1m).
# OHLCV data retrieval and storage completed for 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq (5m).
# OHLCV data retrieval and storage completed for 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq (15m).
# OHLCV data retrieval and storage completed for 6ofzqLnHhobh7cJ4C63rAf5qnKU8AoMxVBi7Kkm6n9wq (1H).
#
# Successfully retrieved 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump - 1m data.
#
# Successfully retrieved 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump - 5m data.
#
# Successfully retrieved 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump - 15m data.
#
# Successfully retrieved 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump - 1H data.
# OHLCV data retrieval and storage completed for 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump (1m).
# OHLCV data retrieval and storage completed for 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump (5m).
# OHLCV data retrieval and storage completed for 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump (15m).
# OHLCV data retrieval and storage completed for 84aessA3Qw4vNFux2EhUSwsVuKUjTAZZ84fVR8aipump (1H).
#
# Successfully retrieved B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump - 1m data.
#
# Successfully retrieved B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump - 5m data.
#
# Successfully retrieved B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump - 15m data.
#
# Successfully retrieved B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump - 1H data.
# OHLCV data retrieval and storage completed for B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump (1m).
# OHLCV data retrieval and storage completed for B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump (5m).
# OHLCV data retrieval and storage completed for B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump (15m).
# OHLCV data retrieval and storage completed for B1L9M9bojyvcw3bet6r63ecRfb7rejraoGXTDMWrpump (1H).
#
# Successfully retrieved 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA - 1m data.
#
# Successfully retrieved 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA - 5m data.
#
# Successfully retrieved 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA - 15m data.
#
# Successfully retrieved 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA - 1H data.
# OHLCV data retrieval and storage completed for 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA (1m).
# OHLCV data retrieval and storage completed for 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA (5m).
# OHLCV data retrieval and storage completed for 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA (15m).
# OHLCV data retrieval and storage completed for 5AvprdviHPERGgqWaELwY58b6t9av5Xz3AWAbnwnPGAA (1H).
#
# Successfully retrieved 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump - 1m data.
#
# Successfully retrieved 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump - 5m data.
#
# Successfully retrieved 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump - 15m data.
#
# Successfully retrieved 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump - 1H data.
# OHLCV data retrieval and storage completed for 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump (1m).
# OHLCV data retrieval and storage completed for 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump (5m).
# OHLCV data retrieval and storage completed for 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump (15m).
# OHLCV data retrieval and storage completed for 3DWUvVBwGgLpG8FVNLn4gUMHBUpRkjNcc3txotfZpump (1H).
#
# Successfully retrieved 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM - 1m data.
#
# Successfully retrieved 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM - 5m data.
#
# Successfully retrieved 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM - 15m data.
#
# Successfully retrieved 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM - 1H data.
# OHLCV data retrieval and storage completed for 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM (1m).
# OHLCV data retrieval and storage completed for 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM (5m).
# OHLCV data retrieval and storage completed for 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM (15m).
# OHLCV data retrieval and storage completed for 2q5RBk7MovbcxwzsYWad2eS7Ns5oPiZGs7tZDyckxWHM (1H).
#
# Successfully retrieved EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump - 1m data.
#
# Successfully retrieved EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump - 5m data.
#
# Successfully retrieved EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump - 15m data.
#
# Successfully retrieved EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump - 1H data.
# OHLCV data retrieval and storage completed for EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump (1m).
# OHLCV data retrieval and storage completed for EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump (5m).
# OHLCV data retrieval and storage completed for EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump (15m).
# OHLCV data retrieval and storage completed for EUjqbTAhVoArG9u5YCA25hAsk7uTCZ5KcDsVmkMNpump (1H).
#
# Successfully retrieved FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump - 1m data.
#
# Successfully retrieved FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump - 5m data.
#
# Successfully retrieved FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump - 15m data.
#
# Successfully retrieved FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump - 1H data.
# OHLCV data retrieval and storage completed for FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump (1m).
# OHLCV data retrieval and storage completed for FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump (5m).
# OHLCV data retrieval and storage completed for FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump (15m).
# OHLCV data retrieval and storage completed for FH5Yuax2hg6ct3tM4hPKXjmBFZ2e9TjLiouUK6fApump (1H).
#
# Successfully retrieved HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV - 1m data.
#
# Successfully retrieved HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV - 5m data.
#
# Successfully retrieved HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV - 15m data.
#
# Successfully retrieved HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV - 1H data.
# OHLCV data retrieval and storage completed for HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV (1m).
# OHLCV data retrieval and storage completed for HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV (5m).
# OHLCV data retrieval and storage completed for HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV (15m).
# OHLCV data retrieval and storage completed for HGPeekaweHshP9ytcXYtPK5T4MTVv6rBmnRbgN6GNZpV (1H).
#
# Successfully retrieved 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj - 1m data.
#
# Successfully retrieved 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj - 5m data.
#
# Successfully retrieved 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj - 15m data.
#
# Successfully retrieved 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj - 1H data.
# OHLCV data retrieval and storage completed for 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj (1m).
# OHLCV data retrieval and storage completed for 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj (5m).
# OHLCV data retrieval and storage completed for 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj (15m).
# OHLCV data retrieval and storage completed for 7uGWXwjosvzFFfgGbQrWLoNrF32DXKm3NVCQxrE6awBj (1H).
#
# Successfully retrieved BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 - 1m data.
#
# Successfully retrieved BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 - 5m data.
#
# Successfully retrieved BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 - 15m data.
#
# Successfully retrieved BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 - 1H data.
# OHLCV data retrieval and storage completed for BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 (1m).
# OHLCV data retrieval and storage completed for BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 (5m).
# OHLCV data retrieval and storage completed for BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 (15m).
# OHLCV data retrieval and storage completed for BmcnEcMipKqhRN9648SooMrnnU3ZgGFzLMZ4HrAeq6g8 (1H).
#
# Successfully retrieved BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump - 1m data.
#
# Successfully retrieved BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump - 5m data.
#
# Successfully retrieved BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump - 15m data.
#
# Successfully retrieved BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump - 1H data.
# OHLCV data retrieval and storage completed for BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump (1m).
# OHLCV data retrieval and storage completed for BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump (5m).
# OHLCV data retrieval and storage completed for BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump (15m).
# OHLCV data retrieval and storage completed for BNUX9Xu5y2wJahFZdT6a5fN4W9xXUUE2zVt8vodtpump (1H).
#
# Successfully retrieved D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe - 1m data.
#
# Successfully retrieved D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe - 5m data.
#
# Successfully retrieved D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe - 15m data.
#
# Successfully retrieved D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe - 1H data.
# OHLCV data retrieval and storage completed for D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe (1m).
# OHLCV data retrieval and storage completed for D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe (5m).
# OHLCV data retrieval and storage completed for D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe (15m).
# OHLCV data retrieval and storage completed for D51NngCMfJXctfEvFue4nkRe9aWpHoAw1JzBZ7RDZFYe (1H).
#
# Successfully retrieved 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ - 1m data.
#
# Successfully retrieved 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ - 5m data.
#
# Successfully retrieved 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ - 15m data.
#
# Successfully retrieved 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ - 1H data.
# OHLCV data retrieval and storage completed for 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ (1m).
# OHLCV data retrieval and storage completed for 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ (5m).
# OHLCV data retrieval and storage completed for 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ (15m).
# OHLCV data retrieval and storage completed for 7N57bZtQQNB92jTXR8Ym2FsJv9PvDrk3vtWtP3YFzXLQ (1H).
#
# Successfully retrieved 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP - 1m data.
#
# Successfully retrieved 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP - 5m data.
#
# Successfully retrieved 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP - 15m data.
#
# Successfully retrieved 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP - 1H data.
# OHLCV data retrieval and storage completed for 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP (1m).
# OHLCV data retrieval and storage completed for 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP (5m).
# OHLCV data retrieval and storage completed for 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP (15m).
# OHLCV data retrieval and storage completed for 8iQCQd8TwARsBGyB7zUvEQqU3LCWXRFPmaKvyTPytPCP (1H).
#
# Successfully retrieved 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump - 1m data.
#
# Successfully retrieved 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump - 5m data.
#
# Successfully retrieved 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump - 15m data.
#
# Successfully retrieved 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump - 1H data.
# OHLCV data retrieval and storage completed for 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump (1m).
# OHLCV data retrieval and storage completed for 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump (5m).
# OHLCV data retrieval and storage completed for 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump (15m).
# OHLCV data retrieval and storage completed for 7M3gDRgozcumFsiTeXwjB8cYxpg7Q9R7rH7rkw2Fpump (1H).
#
# Successfully retrieved bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump - 1m data.
#
# Successfully retrieved bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump - 5m data.
#
# Successfully retrieved bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump - 15m data.
#
# Successfully retrieved bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump - 1H data.
# OHLCV data retrieval and storage completed for bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump (1m).
# OHLCV data retrieval and storage completed for bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump (5m).
# OHLCV data retrieval and storage completed for bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump (15m).
# OHLCV data retrieval and storage completed for bozdUuCb2kdipxES9PzsYHmDVrf7FBTSW3p1CFBpump (1H).
#
# Successfully retrieved EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump - 1m data.
#
# Successfully retrieved EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump - 5m data.
#
# Successfully retrieved EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump - 15m data.
#
# Successfully retrieved EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump - 1H data.
# OHLCV data retrieval and storage completed for EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump (1m).
# OHLCV data retrieval and storage completed for EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump (5m).
# OHLCV data retrieval and storage completed for EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump (15m).
# OHLCV data retrieval and storage completed for EPeVBjdVzwrmeTkSBeKKDJxvWXNRqVezgQMMWTQ2pump (1H).
#
# Successfully retrieved G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump - 1m data.
#
# Successfully retrieved G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump - 5m data.
#
# Successfully retrieved G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump - 15m data.
#
# Successfully retrieved G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump - 1H data.
# OHLCV data retrieval and storage completed for G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump (1m).
# OHLCV data retrieval and storage completed for G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump (5m).
# OHLCV data retrieval and storage completed for G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump (15m).
# OHLCV data retrieval and storage completed for G7BJzg55Afx6Tn6J9CJfA444jMf6QJbVjgQAevNTpump (1H).
#
# Successfully retrieved 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump - 1m data.
#
# Successfully retrieved 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump - 5m data.
#
# Successfully retrieved 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump - 15m data.
#
# Successfully retrieved 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump - 1H data.
# OHLCV data retrieval and storage completed for 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump (1m).
# OHLCV data retrieval and storage completed for 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump (5m).
# OHLCV data retrieval and storage completed for 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump (15m).
# OHLCV data retrieval and storage completed for 61uWHafHrHHs3zuGDCX7uMDczx41kGLsudeM28gspump (1H).
#
# Successfully retrieved Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump - 1m data.
#
# Successfully retrieved Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump - 5m data.
#
# Successfully retrieved Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump - 15m data.
#
# Successfully retrieved Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump - 1H data.
# OHLCV data retrieval and storage completed for Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump (1m).
# OHLCV data retrieval and storage completed for Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump (5m).
# OHLCV data retrieval and storage completed for Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump (15m).
# OHLCV data retrieval and storage completed for Dc29xEisYZXfCV3WHgyhjnwPYS53fZ1n2YPGFEC1pump (1H).
#
# Successfully retrieved BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump - 1m data.
#
# Successfully retrieved BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump - 5m data.
#
# Successfully retrieved BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump - 15m data.
#
# Successfully retrieved BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump - 1H data.
# OHLCV data retrieval and storage completed for BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump (1m).
# OHLCV data retrieval and storage completed for BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump (5m).
# OHLCV data retrieval and storage completed for BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump (15m).
# OHLCV data retrieval and storage completed for BeV4PdcZsNX2WgKgwFTTEgLEnAkbD9CGgxdcVzPHpump (1H).
#
# Successfully retrieved ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump - 1m data.
#
# Successfully retrieved ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump - 5m data.
#
# Successfully retrieved ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump - 15m data.
#
# Successfully retrieved ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump - 1H data.
# OHLCV data retrieval and storage completed for ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump (1m).
# OHLCV data retrieval and storage completed for ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump (5m).
# OHLCV data retrieval and storage completed for ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump (15m).
# OHLCV data retrieval and storage completed for ppgVAATPv5oySBbjzxUTxpQHDKBgVK63EvKhjCepump (1H).
#
# Successfully retrieved 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump - 1m data.
#
# Successfully retrieved 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump - 5m data.
#
# Successfully retrieved 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump - 15m data.
#
# Successfully retrieved 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump - 1H data.
# OHLCV data retrieval and storage completed for 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump (1m).
# OHLCV data retrieval and storage completed for 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump (5m).
# OHLCV data retrieval and storage completed for 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump (15m).
# OHLCV data retrieval and storage completed for 4J4W2tdq8gLLEdrq62HqCAbpPAci8SSQdSVvy6uLpump (1H).
#
# Successfully retrieved 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 - 1m data.
#
# Successfully retrieved 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 - 5m data.
#
# Successfully retrieved 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 - 15m data.
#
# Successfully retrieved 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 - 1H data.
# OHLCV data retrieval and storage completed for 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 (1m).
# OHLCV data retrieval and storage completed for 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 (5m).
# OHLCV data retrieval and storage completed for 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 (15m).
# OHLCV data retrieval and storage completed for 3KAeVfDbU6tZxSD2kqz3Pz6B6f42CW3FdA89GUZ8fw23 (1H).
#
# Successfully retrieved CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump - 1m data.
#
# Successfully retrieved CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump - 5m data.
#
# Successfully retrieved CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump - 15m data.
#
# Successfully retrieved CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump - 1H data.
# OHLCV data retrieval and storage completed for CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump (1m).
# OHLCV data retrieval and storage completed for CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump (5m).
# OHLCV data retrieval and storage completed for CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump (15m).
# OHLCV data retrieval and storage completed for CVNb8Bg7wCrtNTFniaJvxjyFW2cKcoRjKt71Af67pump (1H).
#
# Successfully retrieved 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump - 1m data.
#
# Successfully retrieved 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump - 5m data.
#
# Successfully retrieved 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump - 15m data.
#
# Successfully retrieved 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump - 1H data.
# OHLCV data retrieval and storage completed for 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump (1m).
# OHLCV data retrieval and storage completed for 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump (5m).
# OHLCV data retrieval and storage completed for 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump (15m).
# OHLCV data retrieval and storage completed for 47ixSEoXn9KUnZ9FjCD78NSWDd4RxKUjcwSSYMSnpump (1H).
#
# Successfully retrieved 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump - 1m data.
#
# Successfully retrieved 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump - 5m data.
#
# Successfully retrieved 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump - 15m data.
#
# Successfully retrieved 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump - 1H data.
# OHLCV data retrieval and storage completed for 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump (1m).
# OHLCV data retrieval and storage completed for 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump (5m).
# OHLCV data retrieval and storage completed for 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump (15m).
# OHLCV data retrieval and storage completed for 96DHNZtvy9kqr7cf1r9RotnnWf3WKRf1UZ8CfZ1Ppump (1H).
#
# Successfully retrieved 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump - 1m data.
#
# Successfully retrieved 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump - 5m data.
#
# Successfully retrieved 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump - 15m data.
#
# Successfully retrieved 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump - 1H data.
# OHLCV data retrieval and storage completed for 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump (1m).
# OHLCV data retrieval and storage completed for 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump (5m).
# OHLCV data retrieval and storage completed for 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump (15m).
# OHLCV data retrieval and storage completed for 2CfHy8S118K4RPg9ti2bWFc19tFg48qTmJSvqqbhpump (1H).
#
# Successfully retrieved 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump - 1m data.
#
# Successfully retrieved 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump - 5m data.
#
# Successfully retrieved 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump - 15m data.
#
# Successfully retrieved 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump - 1H data.
# OHLCV data retrieval and storage completed for 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump (1m).
# OHLCV data retrieval and storage completed for 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump (5m).
# OHLCV data retrieval and storage completed for 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump (15m).
# OHLCV data retrieval and storage completed for 4TQzKV6v18aSVJqrCoxhSuQpFbH7wcQGMi1Wwg8dpump (1H).
#
# Successfully retrieved A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump - 1m data.
#
# Successfully retrieved A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump - 5m data.
#
# Successfully retrieved A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump - 15m data.
#
# Successfully retrieved A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump - 1H data.
# OHLCV data retrieval and storage completed for A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump (1m).
# OHLCV data retrieval and storage completed for A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump (5m).
# OHLCV data retrieval and storage completed for A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump (15m).
# OHLCV data retrieval and storage completed for A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump (1H).
#
# Successfully retrieved HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump - 1m data.
#
# Successfully retrieved HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump - 5m data.
#
# Successfully retrieved HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump - 15m data.
#
# Successfully retrieved HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump - 1H data.
# OHLCV data retrieval and storage completed for HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump (1m).
# OHLCV data retrieval and storage completed for HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump (5m).
# OHLCV data retrieval and storage completed for HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump (15m).
# OHLCV data retrieval and storage completed for HqqnXZ8S76rY3GnXgHR9LpbLEKNfxCZASWydNHydpump (1H).
#
# Successfully retrieved FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump - 1m data.
#
# Successfully retrieved FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump - 5m data.
#
# Successfully retrieved FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump - 15m data.
#
# Successfully retrieved FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump - 1H data.
# OHLCV data retrieval and storage completed for FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump (1m).
# OHLCV data retrieval and storage completed for FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump (5m).
# OHLCV data retrieval and storage completed for FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump (15m).
# OHLCV data retrieval and storage completed for FicyuNnH6dHJ5dr24GiEdWENPSeFom8U58QpKYYQpump (1H).
#
# Successfully retrieved 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump - 1m data.
#
# Successfully retrieved 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump - 5m data.
#
# Successfully retrieved 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump - 15m data.
#
# Successfully retrieved 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump - 1H data.
# OHLCV data retrieval and storage completed for 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump (1m).
# OHLCV data retrieval and storage completed for 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump (5m).
# OHLCV data retrieval and storage completed for 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump (15m).
# OHLCV data retrieval and storage completed for 3CjgXtdtBX9dEzEznmeg8AcFiAhCZN3uf8Lfj67jpump (1H).
#
# Successfully retrieved HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump - 1m data.
#
# Successfully retrieved HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump - 5m data.
#
# Successfully retrieved HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump - 15m data.
#
# Successfully retrieved HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump - 1H data.
# OHLCV data retrieval and storage completed for HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump (1m).
# OHLCV data retrieval and storage completed for HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump (5m).
# OHLCV data retrieval and storage completed for HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump (15m).
# OHLCV data retrieval and storage completed for HEi1wV81wVGhyAFC2a8dTJ5iUi48SQZTCx5VqjKzpump (1H).
#
# Successfully retrieved 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb - 1m data.
#
# Successfully retrieved 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb - 5m data.
#
# Successfully retrieved 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb - 15m data.
#
# Successfully retrieved 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb - 1H data.
# OHLCV data retrieval and storage completed for 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb (1m).
# OHLCV data retrieval and storage completed for 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb (5m).
# OHLCV data retrieval and storage completed for 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb (15m).
# OHLCV data retrieval and storage completed for 9thvDfmJRwveDB7NZkB1LrsAEYUSQCbRpK2jmwxegKb (1H).
#
# Successfully retrieved AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump - 1m data.
#
# Successfully retrieved AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump - 5m data.
#
# Successfully retrieved AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump - 15m data.
#
# Successfully retrieved AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump - 1H data.
# OHLCV data retrieval and storage completed for AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump (1m).
# OHLCV data retrieval and storage completed for AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump (5m).
# OHLCV data retrieval and storage completed for AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump (15m).
# OHLCV data retrieval and storage completed for AnGzGiQ6ddzdqWDuWy6vmibqDv8rsT2QKhcgDrwTpump (1H).
#
# Successfully retrieved A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump - 1m data.
#
# Successfully retrieved A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump - 5m data.
#
# Successfully retrieved A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump - 15m data.
#
# Successfully retrieved A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump - 1H data.
# OHLCV data retrieval and storage completed for A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump (1m).
# OHLCV data retrieval and storage completed for A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump (5m).
# OHLCV data retrieval and storage completed for A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump (15m).
# OHLCV data retrieval and storage completed for A1MGHVzbsBJFUMparEw2ffAiUguejrq75tY1SX61pump (1H).
#
# Successfully retrieved 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump - 1m data.
#
# Successfully retrieved 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump - 5m data.
#
# Successfully retrieved 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump - 15m data.
#
# Successfully retrieved 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump - 1H data.
# OHLCV data retrieval and storage completed for 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump (1m).
# OHLCV data retrieval and storage completed for 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump (5m).
# OHLCV data retrieval and storage completed for 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump (15m).
# OHLCV data retrieval and storage completed for 4TNLqKKQrMDqveiyKQjwX5QUuDrgJdzQC53tX68rpump (1H).
#
# Successfully retrieved 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump - 1m data.
#
# Successfully retrieved 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump - 5m data.
#
# Successfully retrieved 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump - 15m data.
#
# Successfully retrieved 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump - 1H data.
# OHLCV data retrieval and storage completed for 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump (1m).
# OHLCV data retrieval and storage completed for 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump (5m).
# OHLCV data retrieval and storage completed for 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump (15m).
# OHLCV data retrieval and storage completed for 7sXmVWeSaLcSyo75NFNjo3gL4B2RXshPvwfhMfxnpump (1H).
#
# Successfully retrieved EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump - 1m data.
#
# Successfully retrieved EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump - 5m data.
#
# Successfully retrieved EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump - 15m data.
#
# Successfully retrieved EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump - 1H data.
# OHLCV data retrieval and storage completed for EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump (1m).
# OHLCV data retrieval and storage completed for EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump (5m).
# OHLCV data retrieval and storage completed for EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump (15m).
# OHLCV data retrieval and storage completed for EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump (1H).
#
# Successfully retrieved 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump - 1m data.
#
# Successfully retrieved 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump - 5m data.
#
# Successfully retrieved 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump - 15m data.
#
# Successfully retrieved 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump - 1H data.
# OHLCV data retrieval and storage completed for 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump (1m).
# OHLCV data retrieval and storage completed for 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump (5m).
# OHLCV data retrieval and storage completed for 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump (15m).
# OHLCV data retrieval and storage completed for 7ty3ruNJebb8RYmzfpUommJnZnCwaoB8RNfqpjLMpump (1H).
#
# Successfully retrieved EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 - 1m data.
#
# Successfully retrieved EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 - 5m data.
#
# Successfully retrieved EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 - 15m data.
#
# Successfully retrieved EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 - 1H data.
# OHLCV data retrieval and storage completed for EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 (1m).
# OHLCV data retrieval and storage completed for EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 (5m).
# OHLCV data retrieval and storage completed for EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 (15m).
# OHLCV data retrieval and storage completed for EcG1YvmtdAeS3Upvcs8UmHkuvQqy5heNAazUAzYZtSM2 (1H).
#
# --------------------------------
# Data Processing Complete
# --------------------------------
# CompletedProcess(args=['python', 'Dataset_ATH_Breakout.py'], returncode=0)

# %%
# Get the most recent folder
base_path = 'Data/New_Token_Data'
current_date = datetime.now().strftime('%Y_%m_%d')
date_folder = os.path.join(base_path, current_date)
ohlcv_folder = os.path.join(date_folder, 'OHLCV_Data')
ohlcv_datetime_folder = ATH_Breakout_Master.get_most_recent_folder(ohlcv_folder)

# Print the name of the folder being used for import
print(f"Importing OHLCV data from folder: {ohlcv_datetime_folder}")

# Import the OHLCV data
imported_ohlcv_data = ATH_Breakout_Master.import_ohlcv_data(ohlcv_datetime_folder)
# Out:
# Importing OHLCV data from folder: Data/New_Token_Data/2024_11_12/OHLCV_Data/2024_Nov_12_0623AM

# %%
def plot_ath_breakouts(imported_ohlcv_data, initial_timeframe='1H', drawdown_percent=10, 
                      max_hours_separation=100, lookback_candles=6, volume_threshold=3,
                      volume_ma_period=5):
    """
    Plot price action showing breakouts to new highs with volume analysis.
    
    Parameters:
    - imported_ohlcv_data: Dictionary of OHLCV data for different timeframes
    - initial_timeframe: Starting timeframe to display (e.g., '1H', '15m', '5m', '1m')
    - drawdown_percent: Minimum required drawdown from previous high (e.g., 10 for 10%)
    - max_hours_separation: Maximum hours allowed between highs (e.g., 100)
    - lookback_candles: Number of recent candles to check for new ATH (e.g., 6)
    - volume_threshold: Minimum volume increase multiplier for highlighting (e.g., 3 for 3x)
    - volume_ma_period: Number of periods for volume moving average calculation (e.g., 5)
    """
    
    def check_recent_ath(df, drawdown_percent, max_hours_separation, lookback_candles):
        if len(df) <= lookback_candles + 10:
            return False, None, None, None
            
        # Get data excluding recent lookback period
        historical_df = df.iloc[:-lookback_candles]
        
        # Find the highest peak before lookback period
        previous_high = historical_df['high'].max()
        previous_high_idx = historical_df['high'].idxmax()
        
        # Get recent candles
        recent_df = df.iloc[-lookback_candles:]
        recent_high = recent_df['high'].max()
        recent_high_idx = recent_df['high'].idxmax()
        
        # Check if we have a new ATH in recent candles
        has_new_ath = recent_high > previous_high
        
        if not has_new_ath:
            return False, None, None, None
            
        # Find lowest point between previous high and recent high
        between_highs_df = df.loc[previous_high_idx:recent_high_idx]
        lowest_close = between_highs_df['close'].min()
        lowest_close_idx = between_highs_df['close'].idxmin()
        
        # Calculate drawdown
        drawdown = ((previous_high - lowest_close) / previous_high) * 100
        
        # Calculate time separation
        time_diff = (recent_high_idx - previous_high_idx).total_seconds() / 3600
        
        # Check conditions
        if drawdown < drawdown_percent or time_diff > max_hours_separation:
            return False, None, None, None
            
        return True, (previous_high, previous_high_idx), (lowest_close, lowest_close_idx), (recent_high, recent_high_idx)
    
    def calculate_volume_increase(df, ma_period):
        """Calculate volume percentage increase relative to prior MA"""
        volume_ma = df['volume'].rolling(window=ma_period).mean().shift(1)
        volume_increase = df['volume'] / volume_ma
        return volume_increase, volume_ma
    
    def has_outliers(df, threshold_multiplier=15.0):
        if df.empty:
            return True
            
        median_price = df['close'].median()
        high_outliers = df['high'] > (median_price * threshold_multiplier)
        
        if not high_outliers.any():
            return False
            
        outlier_indices = df.index[high_outliers]
        for idx in outlier_indices:
            start_idx = max(0, df.index.get_loc(idx) - 3)
            end_idx = min(len(df), df.index.get_loc(idx) + 4)
            window = df.iloc[start_idx:end_idx]
            
            window_median = window['close'].median()
            if df.loc[idx, 'high'] > window_median * threshold_multiplier:
                return True
                
        return False
    
    # Define color scheme
    BACKGROUND_COLOR = '#1e1e1e'
    TEXT_COLOR = '#ffffff'
    GRID_COLOR = 'rgba(51, 51, 51, 0.3)'
    TITLE_COLOR = '#00cc00'
    PREVIOUS_HIGH_COLOR = '#FFA500'  # Neon orange
    NEW_HIGH_COLOR = '#32CD32'      # Lime green
    LOW_POINT_COLOR = '#FF8C00'     # Dark orange
    LEGEND_TEXT_COLOR = '#FFFDD0'   # Heavy cream for legend
    SEPARATOR_COLOR = '#555555'     # Darker gray for separator
    INCREASING_COLOR = '#00ff9d'    # Bright green for up moves
    DECREASING_COLOR = '#ff005b'    # Bright red for down moves
    
    available_timeframes = ['1m', '5m', '15m', '1H']
    token_data = []
    
    # Process market cap data
    base_path = 'Data/New_Token_Data'
    date_folders = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f)) and f.startswith('2024_')]
    most_recent_date = max(date_folders)
    date_folder = os.path.join(base_path, most_recent_date)
    
    summary_folder = os.path.join(date_folder, 'Token_Summary')
    datetime_folders = [f for f in os.listdir(summary_folder) if os.path.isdir(os.path.join(summary_folder, f))]
    most_recent_datetime = max(datetime_folders)
    summary_datetime_folder = os.path.join(summary_folder, most_recent_datetime)
    
    mc_files = [f for f in os.listdir(summary_datetime_folder) if f.startswith('new_tokens_mc') and f.endswith('.csv')]
    latest_mc_file = os.path.join(summary_datetime_folder, mc_files[0])
    market_caps = pd.read_csv(latest_mc_file, index_col=0)['Market Cap']
    
    # Calculate and filter tokens with new ATHs
    for token_address, timeframes in imported_ohlcv_data.items():
        if initial_timeframe not in timeframes:
            continue
            
        df_initial = timeframes[initial_timeframe]
        if df_initial.empty or has_outliers(df_initial):
            continue
            
        has_pattern, first_high_data, low_point_data, new_high_data = check_recent_ath(
            df_initial, drawdown_percent, max_hours_separation, lookback_candles)
            
        if has_pattern:
            token_data.append({
                'address': token_address,
                'first_high_data': first_high_data,
                'low_point_data': low_point_data,
                'new_high_data': new_high_data
            })
    
    # Create plots for each token
    for token_data in token_data:
        token_address = token_data['address']
        gmgn_link = f"https://gmgn.ai/sol/token/{token_address}"
        dexscreener_link = f"https://dexscreener.com/solana/{token_address}"
        print(f"\nProcessing: {gmgn_link}\n{dexscreener_link}")
        
        timeframes = imported_ohlcv_data[token_address]
        market_cap = ATH_Breakout_Master.format_number(market_caps.get(token_address, 0))
        
        # Create subplots with shared x-axis and secondary y-axis for volume
        fig = make_subplots(rows=2, cols=1, 
                           shared_xaxes=True,
                           vertical_spacing=0.08,
                           row_heights=[0.7, 0.3],
                           specs=[[{"type": "candlestick"}],
                                 [{"secondary_y": True}]])
        
        timeframe_volumes = {}
        
        for tf in available_timeframes:
            if tf not in timeframes:
                continue
                
            df = timeframes[tf].copy()
            if df.empty:
                continue
                
            timeframe_volumes[tf] = df['volume'].iloc[-1]
            
            # Add candlestick chart
            fig.add_trace(
                go.Candlestick(
                    x=df.index,
                    open=df['open'],
                    high=df['high'],
                    low=df['low'],
                    close=df['close'],
                    name="Price",
                    showlegend=False,
                    increasing_line_color=INCREASING_COLOR,
                    decreasing_line_color=DECREASING_COLOR,
                    visible=(tf == initial_timeframe)
                ),
                row=1, col=1
            )
            
            # Add previous high triangle
            first_high, first_idx = token_data['first_high_data']
            fig.add_trace(
                go.Scatter(
                    x=[first_idx],
                    y=[first_high],
                    mode='markers+text',
                    marker=dict(
                        symbol='triangle-up',
                        size=20,
                        color=PREVIOUS_HIGH_COLOR,
                        line=dict(color=PREVIOUS_HIGH_COLOR, width=2)
                    ),
                    name='Previous High',
                    showlegend=True,
                    legendgroup="price_markers",
                    legendgrouptitle_font=dict(color=LEGEND_TEXT_COLOR),
                    visible=(tf == initial_timeframe)
                ),
                row=1, col=1
            )
            
            # Add lowest point with drawdown %
            low_point, low_idx = token_data['low_point_data']
            drawdown = ((first_high - low_point) / first_high) * 100
            fig.add_trace(
                go.Scatter(
                    x=[low_idx],
                    y=[low_point],
                    mode='markers+text',
                    marker=dict(
                        symbol='diamond',
                        size=10,
                        color=LOW_POINT_COLOR,
                        line=dict(color=LOW_POINT_COLOR, width=2)
                    ),
                    text=f"{int(drawdown)}%",
                    textposition="bottom center",
                    textfont=dict(color=TEXT_COLOR),
                    name='Lowest Close',
                    showlegend=True,
                    legendgroup="price_markers",
                    legendgrouptitle_font=dict(color=LEGEND_TEXT_COLOR),
                    visible=(tf == initial_timeframe)
                ),
                row=1, col=1
            )
            
            # Add new high triangle
            new_high, new_idx = token_data['new_high_data']
            fig.add_trace(
                go.Scatter(
                    x=[new_idx],
                    y=[new_high],
                    mode='markers+text',
                    marker=dict(
                        symbol='triangle-up',
                        size=20,
                        color=NEW_HIGH_COLOR,
                        line=dict(color=NEW_HIGH_COLOR, width=2)
                    ),
                    name='New High',
                    showlegend=True,
                    legendgroup="price_markers",
                    legendgrouptitle_font=dict(color=LEGEND_TEXT_COLOR),
                    visible=(tf == initial_timeframe)
                ),
                row=1, col=1
            )
            
            # Calculate volume colors and volume increase
            colors = [INCREASING_COLOR if df['close'].iloc[i] >= df['open'].iloc[i] 
                     else DECREASING_COLOR for i in range(len(df))]
            
            volume_increase, _ = calculate_volume_increase(df, volume_ma_period)
            
            # Add volume bars
            fig.add_trace(
                go.Bar(
                    x=df.index,
                    y=df['volume'],
                    name="Volume",
                    marker_color=colors,
                    showlegend=False,
                    visible=(tf == initial_timeframe)
                ),
                row=2, col=1,
                secondary_y=False
            )
            
            # Add volume spike markers with matching colors
            # Inside the plotting loop, replace the volume spike section:
            volume_spikes = volume_increase[volume_increase >= volume_threshold]
            if not volume_spikes.empty:
                # Calculate colors based on price change percentage
                spike_colors = []
                for timestamp in volume_spikes.index:
                    candle_idx = df.index.get_loc(timestamp)
                    open_price = df['open'].iloc[candle_idx]
                    close_price = df['close'].iloc[candle_idx]
                    
                    # Calculate percentage change
                    pct_change = abs((close_price - open_price) / open_price * 100)
                    
                    # Adjust brightness based on percentage change
                    # Higher percentage = brighter color
                    brightness = min(100 + (pct_change * 2), 255) / 255  # Caps at 255
                    
                    if close_price >= open_price:
                        # For green candles: brighten the base green color
                        r = int(0 * brightness)
                        g = int(255 * brightness)
                        b = int(157 * brightness)
                        color = f'rgb({r},{g},{b})'
                    else:
                        # For red candles: brighten the base red color
                        r = int(255 * brightness)
                        g = int(0 * brightness)
                        b = int(91 * brightness)
                        color = f'rgb({r},{g},{b})'
                        
                    spike_colors.append(color)
                
                fig.add_trace(
                    go.Scatter(
                        x=volume_spikes.index,
                        y=volume_spikes,
                        mode='markers+text',
                        marker=dict(
                            symbol='circle',
                            size=22,
                            color=spike_colors,
                            line=dict(color=spike_colors, width=2)
                        ),
                        text=[f"{int(v) if v != float('inf') else '∞'}" for v in volume_spikes],
                        textposition="middle center",
                        textfont=dict(
                            color='black',
                            size=11,
                            family="Arial Black"
                        ),
                        name=f"Volume Spikes (≥{volume_threshold}x)",
                        showlegend=True,
                        legendgroup="volume_markers",
                        legendgrouptitle_font=dict(color=LEGEND_TEXT_COLOR),
                        visible=(tf == initial_timeframe)
                    ),
                    row=2, col=1,
                    secondary_y=True
                )
        
        # Update layout
        fig.update_layout(
            height=800,
            width=1200,
            paper_bgcolor=BACKGROUND_COLOR,
            plot_bgcolor=BACKGROUND_COLOR,
            margin=dict(r=50, t=80, l=50, b=50),
            showlegend=True,
            legend=dict(
                font=dict(color=LEGEND_TEXT_COLOR),
                bgcolor=BACKGROUND_COLOR,
                bordercolor=GRID_COLOR
            ),
            hovermode='x unified',
            title=dict(
                text=f"Drawdown: {drawdown:.1f}% | Market Cap: {market_cap}",
                font=dict(size=16, color=TITLE_COLOR),
                x=0.5,
                y=0.95
            ),
            xaxis_rangeslider_visible=False
        )
        
        # Add separator line between plots
        fig.add_shape(
            type="line",
            x0=0,
            y0=0,
            x1=1,
            y1=0,
            xref="paper",
            yref="paper",
            line=dict(
                color=SEPARATOR_COLOR,
                width=2,
                dash="solid"
            )
        )
        
        # Update axes properties
        for i in range(2):
            fig.update_xaxes(
                showgrid=True,
                gridcolor=GRID_COLOR,
                showline=True,
                linecolor=GRID_COLOR,
                tickfont=dict(color=TEXT_COLOR),
                row=i+1, col=1
            )
            
            fig.update_yaxes(
                showgrid=True,
                gridcolor=GRID_COLOR,
                showticklabels=True,
                showline=True,
                linecolor=GRID_COLOR,
                zeroline=False,
                fixedrange=True,
                tickfont=dict(color=TEXT_COLOR),
                row=i+1, col=1
            )
        
        # Update secondary y-axis for volume spikes
        fig.update_yaxes(
            title_text="Volume Multiple",
            title_font=dict(color=TEXT_COLOR),
            tickfont=dict(color=TEXT_COLOR),
            row=2, col=1,
            secondary_y=True
        )
        
        fig.show()

# Example usage with typical values
plot_ath_breakouts(imported_ohlcv_data, 
                   initial_timeframe='15m',          # Starting timeframe
                   drawdown_percent=30,             # 10% minimum drawdown
                   max_hours_separation=24,        # 100 hours max between highs
                   lookback_candles=6,             # Check last 6 candles for new ATH
                   volume_threshold=6,             # Show volume spikes >= 3x MA
                   volume_ma_period=4)             # 4-period volume MA
# Out:
# Processing: https://gmgn.ai/sol/token/A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump
# https://dexscreener.com/solana/A6jBzMFsrxGEi2s8SDejWHojGu2j2RF7LvwTD2NTpump
# <div>                            <div id="0244221c-3f60-4458-9319-615500372029" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0244221c-3f60-4458-9319-615500372029")) {                    Plotly.newPlot(                        "0244221c-3f60-4458-9319-615500372029",                        [{"close":[8.32946798515145e-05,9.27553193526079e-05,9.74612052534022e-05,0.000140519779627,0.0001544597650857,0.0001802994804298,0.0002022045535144,0.0002048017505535,0.0001662740858397,0.0001798125053581,0.0001405784215422,0.0001325795756363,0.0001380784106246,0.0001485954590567,0.0001274513977315,8.775816076455463e-05,9.311335344784466e-05,9.172464912235106e-05,0.0001033400417597,0.0001078125386609,0.000112505199033,0.0001050897557012,0.0001078192171514,0.0001120319673076,0.0001065721208267,8.536223271630718e-05,8.873452598827885e-05,9.542853295282724e-05,0.0001041096043905,0.000108518764853,0.0001046669124825,0.0001090431561215,0.000109411135602,0.0001139400602409
0.0004392208595765,0.0004368665870728,0.0004431709871393,0.0004452515298431,0.0004285540652655,0.0004299147454612,0.0004371201042458,0.0004309689030291,0.0004438458406899,0.000454099520751,0.0004556549298682,0.0004692553030999,0.0004821112517434,0.0004590936574271,0.0004832869092789,0.0004934370165709,0.0005537215571502,0.0005418222453893,0.000477961224469,0.00049868853205,0.0005174923855289,0.0004895418328859,0.0004897573595916,0.0004933253912066,0.0004989702412395,0.0004757812620583,0.0004812664986727,0.0005204924990673,0.000509862140422,0.0004992151499845,0.0005315923612133,0.0005528826075954,0.0005333289073751,0.0005510942526384,0.0005424835729739,0.0005426992755331,0.0005469911417869,0.0005699140003072,0.0005817636227867,0.000566579624122,0.000576004754458,0.0006105055083704,0.0005942979916601,0.0005921443662927,0.0005794051290659,0.0006233227904991,0.0006250434895023,0.000673330040045,0.0007303657382716,0.0007637654921025,0.0006923910699902,0.0006822524191513,0.0007157309634508,0.0007452457215827,0.0007600768536596,0.0007816438982618,0.0007956255322876,0.000806785220779,0.0008253826713884,0.0008766565856678,0.000892905602894,0.000845270022914,0.0008200001216147,0.0008695514625683,0.0008942313769203,0.0008620005633144,0.0008172932704454,0.0008393230573736,0.0008567808369112,0.0008029420166353,0.0008019526804753,0.0007504534338492,0.00081177288261,0.0008405027895046,0.0008954514020906,0.0008998092761668,0.0008913801825245,0.0008990845227755,0.000924286442917,0.0009092422544641,0.0009331287943295,0.0009081515896585,0.0008790955750787,0.0008512482653803,0.0008211717776544,0.0008349629582912,0.0008014020737674,0.0007506731350406,0.0007290267454558,0 ...

# %%
def plot_ath_breakouts(imported_ohlcv_data, initial_timeframe='5m'):
    """
    Plot price action showing previous ATH and new ATH from recent candles.
    Mobile-optimized with clean display and improved visuals.
    """
    
    def check_recent_ath(df, lookback=4):
        if len(df) <= lookback:
            return False, None, None
            
        # Get previous ATH (excluding last 4 candles)
        historical_df = df.iloc[:-lookback]
        previous_ath = historical_df['high'].max()
        previous_ath_idx = historical_df['high'].idxmax()
        
        # Check last 4 candles
        recent_df = df.iloc[-lookback:]
        recent_high = recent_df['high'].max()
        recent_ath_idx = recent_df['high'].idxmax()
        
        has_new_ath = recent_high > previous_ath
        return has_new_ath, (previous_ath, previous_ath_idx), (recent_high, recent_ath_idx)
    
    def create_timeframe_annotations(timeframe, market_cap, volume):
        formatted_volume = ATH_Breakout_Master.format_number(volume)
        return [
            dict(
                text=f"<b>Timeframe:</b> {timeframe}",
                x=0.2,
                y=-0.07,
                xref="paper",
                yref="paper",
                showarrow=False,
                font=dict(size=16, color=TITLE_COLOR),
                bgcolor=BACKGROUND_COLOR,
                bordercolor=GRID_COLOR,
                borderwidth=1,
                borderpad=8
            ),
            dict(
                text=f"<b>Current MC:</b> {market_cap}",
                x=0.5,
                y=-0.07,
                xref="paper",
                yref="paper",
                showarrow=False,
                font=dict(size=16, color=TITLE_COLOR),
                bgcolor=BACKGROUND_COLOR,
                bordercolor=GRID_COLOR,
                borderwidth=1,
                borderpad=8
            ),
            dict(
                text=f"<b>Prior Candle Vol:</b> {formatted_volume}",
                x=0.8,
                y=-0.07,
                xref="paper",
                yref="paper",
                showarrow=False,
                font=dict(size=16, color=TITLE_COLOR),
                bgcolor=BACKGROUND_COLOR,
                bordercolor=GRID_COLOR,
                borderwidth=1,
                borderpad=8
            )
        ]
    
    def has_outliers(df, threshold_multiplier=15.0):
        if df.empty:
            return True
            
        median_price = df['close'].median()
        high_outliers = df['high'] > (median_price * threshold_multiplier)
        
        if not high_outliers.any():
            return False
            
        outlier_indices = df.index[high_outliers]
        for idx in outlier_indices:
            start_idx = max(0, df.index.get_loc(idx) - 3)
            end_idx = min(len(df), df.index.get_loc(idx) + 4)
            window = df.iloc[start_idx:end_idx]
            
            window_median = window['close'].median()
            if df.loc[idx, 'high'] > window_median * threshold_multiplier:
                return True
                
        return False
    
    # Define color scheme with fainter grid
    BACKGROUND_COLOR = '#1e1e1e'
    TEXT_COLOR = '#ffffff'
    GRID_COLOR = 'rgba(51, 51, 51, 0.3)'
    TITLE_COLOR = '#00cc00'
    PREVIOUS_ATH_COLOR = '#FFD700'  # Gold for previous ATH
    NEW_ATH_COLOR = '#FF0000'       # Bright red for new ATH
    
    available_timeframes = ['1m', '5m', '15m', '1H']
    token_data = []
    
    # Process market cap data
    base_path = 'Data/New_Token_Data'
    date_folders = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f)) and f.startswith('2024_')]
    most_recent_date = max(date_folders)
    date_folder = os.path.join(base_path, most_recent_date)
    
    summary_folder = os.path.join(date_folder, 'Token_Summary')
    datetime_folders = [f for f in os.listdir(summary_folder) if os.path.isdir(os.path.join(summary_folder, f))]
    most_recent_datetime = max(datetime_folders)
    summary_datetime_folder = os.path.join(summary_folder, most_recent_datetime)
    
    mc_files = [f for f in os.listdir(summary_datetime_folder) if f.startswith('new_tokens_mc') and f.endswith('.csv')]
    latest_mc_file = os.path.join(summary_datetime_folder, mc_files[0])
    market_caps = pd.read_csv(latest_mc_file, index_col=0)['Market Cap']
    
    # Calculate and filter tokens with new ATHs
    for token_address, timeframes in imported_ohlcv_data.items():
        if initial_timeframe not in timeframes:
            continue
            
        df_initial = timeframes[initial_timeframe]
        if df_initial.empty or has_outliers(df_initial):
            continue
            
        has_new_ath, previous_ath_data, recent_ath_data = check_recent_ath(df_initial)
        if has_new_ath:
            token_data.append({
                'address': token_address,
                'previous_ath_data': previous_ath_data,
                'recent_ath_data': recent_ath_data
            })
    
    # Create plots for each token
    for token_data in token_data:
        token_address = token_data['address']
        gmgn_link = f"https://gmgn.ai/sol/token/{token_address}"
        dexscreener_link = f"https://dexscreener.com/solana/{token_address}"
        print(f"\nProcessing: {gmgn_link}\n{dexscreener_link}")
        
        timeframes = imported_ohlcv_data[token_address]
        market_cap = ATH_Breakout_Master.format_number(market_caps.get(token_address, 0))
        
        fig = go.Figure(layout_xaxis_rangeslider_visible=False)
        timeframe_traces = {}
        timeframe_volumes = {}
        
        # Process each timeframe
        for tf in available_timeframes:
            if tf not in timeframes:
                continue
                
            df = timeframes[tf]
            if df.empty:
                continue
                
            traces = []
            timeframe_volumes[tf] = df['volume'].iloc[-1]
            
            # Add candlestick chart
            traces.append(go.Candlestick(
                x=df.index,
                open=df['open'],
                high=df['high'],
                low=df['low'],
                close=df['close'],
                name="Price",
                showlegend=False,
                increasing_line_color='#00ff9d',
                decreasing_line_color='#ff005b',
                visible=(tf == initial_timeframe)
            ))
            
            # Add previous ATH star
            prev_ath, prev_idx = token_data['previous_ath_data']
            traces.append(go.Scatter(
                x=[prev_idx],
                y=[prev_ath],
                mode='markers',
                marker=dict(
                    symbol='star',
                    size=24,
                    color=PREVIOUS_ATH_COLOR,
                    line=dict(
                        color=PREVIOUS_ATH_COLOR,
                        width=2
                    )
                ),
                name='Previous ATH',
                showlegend=True,
                visible=(tf == initial_timeframe)
            ))
            
            # Add new ATH star
            recent_ath, recent_idx = token_data['recent_ath_data']
            traces.append(go.Scatter(
                x=[recent_idx],
                y=[recent_ath],
                mode='markers',
                marker=dict(
                    symbol='star',
                    size=24,
                    color=NEW_ATH_COLOR,
                    line=dict(
                        color=NEW_ATH_COLOR,
                        width=2
                    )
                ),
                name='New ATH',
                showlegend=True,
                visible=(tf == initial_timeframe)
            ))
            
            timeframe_traces[tf] = traces
        
        # Create mobile-friendly timeframe buttons
        buttons = []
        for tf in available_timeframes:
            if tf not in timeframe_traces:
                continue
                
            visible_traces = []
            for other_tf in timeframe_traces:
                visible_traces.extend([tf == other_tf] * len(timeframe_traces[other_tf]))
            
            tf_annotations = create_timeframe_annotations(
                tf,
                market_cap,
                timeframe_volumes[tf]
            )
            
            buttons.append(dict(
                label=tf,
                method="update",
                args=[
                    {"visible": visible_traces},
                    {"annotations": tf_annotations}
                ]
            ))
        
        # Add all traces to the figure
        for traces in timeframe_traces.values():
            fig.add_traces(traces)
        
        # Create initial annotations
        initial_annotations = create_timeframe_annotations(
            initial_timeframe,
            market_cap,
            timeframe_volumes[initial_timeframe]
        )
        
        # Update layout with fixed dimensions
        fig.update_layout(
            height=800,
            width=1200,
            paper_bgcolor=BACKGROUND_COLOR,
            plot_bgcolor=BACKGROUND_COLOR,
            margin=dict(r=50, t=80, l=50, b=50),
            showlegend=True,  # Changed to True to show ATH stars in legend
            hovermode='x unified',
            annotations=initial_annotations,
            updatemenus=[dict(
                type="buttons",
                direction="right",
                x=0.5,
                y=1.05,
                xanchor="center",
                yanchor="bottom",
                showactive=True,
                active=available_timeframes.index(initial_timeframe),
                buttons=buttons,
                bgcolor=BACKGROUND_COLOR,
                bordercolor="#555555",
                borderwidth=2,
                font=dict(
                    size=16,
                    color=TITLE_COLOR
                ),
                pad=dict(r=20, t=10, b=10, l=20)
            )],
            xaxis=dict(
                showticklabels=False,
                showgrid=True,
                gridcolor=GRID_COLOR,
                showline=True,
                linecolor=GRID_COLOR,
                rangeslider=dict(visible=False)
            ),
            yaxis=dict(
                showgrid=True,
                gridcolor=GRID_COLOR,
                showticklabels=False,
                showline=False,
                zeroline=False,
                fixedrange=True
            )
        )
        
        fig.show()

# Call the function
plot_ath_breakouts(imported_ohlcv_data, initial_timeframe='15m')
# Out:
# Processing: https://gmgn.ai/sol/token/8pDajezgfVP6yTAVAgLkosTE4PKCQyc9mpHdPiqvp